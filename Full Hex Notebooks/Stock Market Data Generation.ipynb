# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"Pacific/Honolulu\"")

# %%
hex_project_id = _hex_json.loads("\"b1dcbc69-1f89-42b8-99ac-329312ba03f1\"")

# %%
hex_project_name = _hex_json.loads("\"Stock Market Data Generation\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
# !pip install pandas-gbq

# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
import csv

with open('2023-07-02 4_06pm.csv') as f:
    reader = csv.reader(f)
    rows = [row for row in reader]

for row in rows:
    marketcap = row[rows[0].index('MARKETCAP')]  
    if 'e' in marketcap:  
        mantissa, exponent = marketcap.split('e')  
        exponent = int(exponent)
        mantissa = float(mantissa)
        row[rows[0].index('MARKETCAP')] = int(mantissa * (10**exponent))  

with open('2023-07-02 4_06pm.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
pip install yfinance

# %%
import requests 
import csv

def get_company_profiles(tickers):
    url = "https://discountingcashflows.com/api/profile/{}"
    rows = [] 
    
    for ticker in tickers:
        response = requests.get(url.format(ticker)) 
        data = response.json()[0]
        
        rows.append({
            "ticker": ticker,
            "company_name": data["companyName"],  
            "industry": data["industry"],
            "sector": data["sector"],
            "fullTimeEmployees": data["fullTimeEmployees"],
            "ipoDate": data["ipoDate"],
            "exchangeShortName": data["exchangeShortName"],
            "country": data["country"],
            "mktCap": data["mktCap"],
            "cik": data["cik"],
            "isin": data["isin"],
            "website": data["website"],
            "description": data["description"],
            "isEtf": data["isEtf"],
            "isFund": data["isFund"]
        })
        
    with open("company_profiles.csv", "w") as f:
        writer = csv.writer(f)
        writer.writerow([
            "ticker", 
            "company_name",
            "industry",
            "sector",
            "fullTimeEmployees",
            "ipoDate",
            "exchangeShortName",
            "country",
            "mktCap",
            "cik",
            "isin",
            "website",
            "description",
            "isEtf",
            "isFund"
        ])
        writer.writerows([row.values() for row in rows])
        
tickers = ['IMVT', 'ETNB', 'SMCI', 'ACLS', 'TGTX', 'RMBS', 'ACLX', 'WING', 'AVDL', 'SGML', 'ISEE', 'NUVL', 'NVDA', 'SYM']
get_company_profiles(tickers)

# %% [markdown]
# Get SP500 Tickers - [https://fmpcloud.io/api/v3/sp500_constituent?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86](https://fmpcloud.io/api/v3/sp500_constituent?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86)

# %%
import requests
import csv

api_url = "https://fmpcloud.io/api/v3/sp500_constituent?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"
csv_filename = "sp500_constituents.csv"

# Send GET request to the API endpoint
response = requests.get(api_url)

# Check if the request was successful
if response.status_code == 200:
    # Decode the response content
    data = response.content.decode("utf-8")

    # Save data to a CSV file
    with open(csv_filename, "w", newline="") as file:
        writer = csv.writer(file)
        reader = csv.reader(data.splitlines())

        # Write each row to the CSV file
        for row in reader:
            writer.writerow(row)

    print(f"Data saved to {csv_filename} successfully.")
else:
    print("Error occurred while accessing the API.")

# %%
sp500_symbol_list = sp500_symbols['symbol'].tolist()[1:]

print(sp500_symbol_list)

# %% [markdown]
# Manually load tickers

# %%
data = '''AMZN
INTC
LRCX
META
BABA
GIS
KMI
KO
MCD
MDT
MMM
TEL
USB
XYL
URNM
ABNB
AMAT
ASML
KLAC
KLIC
MRAM
SWKS
UROY
VMFXX
BWXT
DOCS
SPOT
SILXY
CLLNY
SRUUF
YLLXF
IGN
VGT
VUG
SOXX
VONG
JEPI
SCHD
VB
VIG
VTI
FXAIX
SPAXX
VXUS
TWCGX
SPY
EMCLOUD
COMP
FROG
MCHP
IRDM
NVEC
MXL
OPRA
BELFB
EXTR
IDCC
ON
HLIT
PLAB
VEEV
TTD
SHOP
CDLX
ZI
DV
S
ZS
CRWD
ADSK
PANW
MSI
ANET
EQIX
EGIO
DOCN
NET
RKLB
ASTS
COIN
NCNO
FISV
ENPH
TOELY
QRVO
BESI
VSH
AEHR
TXN
SLAB
CRUS
NXPI
AVGO
MPWR
LSCC
SNPS
CDNS
APH
CGNX
PLPC
SYM
IOT
TMO
DHR
TT
IRM
SEIC
NOW
BDC
DIOD
JBL
CARG
CSGS
ADBE
CRM
NOW
SHOP
WDAY
PYPL
SNOW
CRWD
TEAM
DDOG
SQ
MDB
VEEV
ZS
HUBS
NET
ZM
OKTA
TWLO
PAYC
PATH
DBX
PCTY
DOCU
TOST
ESTC
PCOR
APPF
GTLB
MNDY
QLYS
BILL
SMAR
CFLT
FRSH
WIX
ZI
WK
S
FIVN
BRZE
TENB
ASAN
SQSP
CXM
CWAN
BOX
BL
NCNO
AI
SPT
FROG
RNG
DOCN
FSLY
PD
QTWO
AVDX
AVPT
AMPL
ZUO
EVBG
DH
YEXT
OLO
BIGC
VMEO
WEAV
EGHT
DOMO
NOVT
IPGP
COHR
GFS
MU
WOLF
TXN
INTC
NVDA
ADI
QCOM
NXPI
TER
ALGM
MRVL
SWKS
ASML
AMD
MPWR
ON
LSCC
QRVO
AVGO
MCHP
AMAT
LRCX
ENTG
KLAC
TSM
SYNA
MKL'''

tickers = data.split('\n')
print(tickers)
# Out:
# ['AMZN', 'INTC', 'LRCX', 'META', 'BABA', 'GIS', 'KMI', 'KO', 'MCD', 'MDT', 'MMM', 'TEL', 'USB', 'XYL', 'URNM', 'ABNB', 'AMAT', 'ASML', 'KLAC', 'KLIC', 'MRAM', 'SWKS', 'UROY', 'VMFXX', 'BWXT', 'DOCS', 'SPOT', 'SILXY', 'CLLNY', 'SRUUF', 'YLLXF', 'IGN', 'VGT', 'VUG', 'SOXX', 'VONG', 'JEPI', 'SCHD', 'VB', 'VIG', 'VTI', 'FXAIX', 'SPAXX', 'VXUS', 'TWCGX', 'SPY', 'EMCLOUD', 'COMP', 'FROG', 'MCHP', 'IRDM', 'NVEC', 'MXL', 'OPRA', 'BELFB', 'EXTR', 'IDCC', 'ON', 'HLIT', 'PLAB', 'VEEV', 'TTD', 'SHOP', 'CDLX', 'ZI', 'DV', 'S', 'ZS', 'CRWD', 'ADSK', 'PANW', 'MSI', 'ANET', 'EQIX', 'EGIO', 'DOCN', 'NET', 'RKLB', 'ASTS', 'COIN', 'NCNO', 'FISV', 'ENPH', 'TOELY', 'QRVO', 'BESI', 'VSH', 'AEHR', 'TXN', 'SLAB', 'CRUS', 'NXPI', 'AVGO', 'MPWR', 'LSCC', 'SNPS', 'CDNS', 'APH', 'CGNX', 'PLPC', 'SYM', 'IOT', 'TMO', 'DHR', 'TT', 'IRM', 'SEIC', 'NOW', 'BDC', 'DIOD', 'JBL', 'CARG', 'CSGS', 'ADBE', 'CRM', 'NOW', 'SHOP', 'WDAY', 'PYPL', 'SNOW', 'CRWD', 'TEAM', 'DDOG', 'SQ', 'MDB', 'VEEV', 'ZS', 'HUBS', 'NET', 'ZM', 
# ...

# %%
import pandas as pd

# Define the list of tickers
tickers = tickers

# Initialize an empty list to store the dataframes for each ticker
dfs = []

# Loop through each ticker and pull the data
for ticker in tickers:
    url = f'https://fmpcloud.io/api/v3/profile/{ticker}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86'
    df = pd.read_csv(url)
    dfs.append(df)

# Concatenate all the dataframes into a single dataframe
df_all = pd.concat(dfs, axis=0)

# Save the final dataframe as a CSV file
df_all.to_csv('company_info.csv', index=False)

# Display a message to confirm that the file has been saved
print('CSV file saved')

# %%
import pandas as pd

# Read the CSV file into a dataframe
df = pd.read_csv('company_info.csv')

# Select the desired columns
cols = ['symbol', 'companyName', 'industry', 'sector', 'fullTimeEmployees', 'ipoDate', 'exchangeShortName', 'country', 'mktCap', 'cik', 'isin', 'website', 'description', 'isEtf', 'isFund']
df_selected = df[cols]

# Save the selected dataframe as a CSV file
df_selected.to_csv('company_info.csv', index=False)

# Display a message to confirm that the file has been saved
print('CSV file saved')

# %%
# Read the CSV file into a dataframe
df = pd.read_csv('company_info.csv')

# Convert the mktCap column to a numerical value
df['mktCap'] = pd.to_numeric(df['mktCap'], errors='coerce')

# Define the classify_market_cap() function
def classify_market_cap(market_cap):
    if market_cap >= 200000000000:
        return 'Mega-cap'
    elif market_cap >= 10000000000:
        return 'Large-cap'
    elif market_cap >= 2000000000:
        return 'Mid-cap'
    elif market_cap >= 300000000:
        return 'Small-cap'
    elif market_cap >= 50000000:
        return 'Micro-cap'
    else:
        return 'Nano-cap'

# Apply the classify_market_cap() function to the mktCap column and store the result in a new column
df['market_cap_category'] = df['mktCap'].apply(classify_market_cap)

# Write the modified dataframe to a new CSV file with the same name as the original file
df.to_csv('company_info.csv', index=False)

# %% [markdown]
# ### **Get Weekly Stock Prices and Returns Data **

# %%
import pandas as pd
import requests
import json 
import csv
import datetime

# List of tickers
tickers = tickers

# CSV file name 
csv_file = "monthly_prices.csv"

# Open CSV file
with open(csv_file, "w", newline='') as f:   
    csv_writer = csv.writer(f)

    # Write CSV header  
    csv_writer.writerow(["Ticker", "Date", "Close"])  

    for ticker in tickers:
        # API URL
        url = f"https://fmpcloud.io/api/v3/historical-price-full/{ticker}?serietype=line&apikey=a726d5acabd86910ef2749315f5eaa86"

        # Get API response
        response = requests.get(url)
        data = json.loads(response.text)['historical']  

        # Loop through data
        for obj in data:
            date = datetime.datetime.strptime(obj["date"], "%Y-%m-%d")
            if date.day == 1:  # First day of the month    
                csv_writer.writerow([ticker, date.strftime("%Y-%m-%d"), obj["close"]])

# %%
import yfinance as yf  
import csv  
import datetime  
import pandas as pd

def weekly_prices(ticker_symbols, output_file):
    """ Gets the weekly closing price for a set of stock tickers """
    start_date = '1950-01-01'  
    
    last_wednesday = datetime.datetime.now()
    while last_wednesday.weekday() != 2: 
        last_wednesday -= datetime.timedelta(days=1)
    end_date = last_wednesday.date()  
    
    weekly_returns = []
    
    for symbol in ticker_symbols:
        stock = yf.Ticker(symbol)
        history = stock.history(start=start_date, end=end_date)
        
        # Check if index is DatetimeIndex, if not skip 
        if not isinstance(history.index, pd.DatetimeIndex):
            continue   
        
        try:  
            weekly_close = history.resample('W-FRI').last() 
        except KeyError:
            continue 
            
        for date in weekly_close.index:
            price = weekly_close.loc[date]['Close']
            weekly_returns.append({
                'symbol': symbol, 
                'date': date.strftime('%Y-%m-%d'), 
                'price': price
            })      
  
    # Write to CSV
    with open(output_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['symbol', 'date', 'price'])
        writer.writerows([[d['symbol'], d['date'], d['price']] for d in weekly_returns])

# %%
tickers = tickers
output_file = 'weekly_prices.csv'

weekly_prices(tickers, output_file)

# %%
import yfinance as yf
import csv
import datetime
import pandas as pd

def calculate_weekly_returns(ticker_symbols, output_file):
    """
    Calculates the weekly returns of one or more stocks over their entire history, breaking out the returns into
    dividends and capital gains.

    :param ticker_symbols: A list of ticker symbols to calculate returns for.
    :param output_file: The name of the CSV file to output results to.
    :return: A list of tuples, where each tuple represents the start and end prices for a given week.
    """
    today = datetime.date.today().strftime('%Y-%m-%d')
    
    weekly_returns = []
    for symbol in ticker_symbols:
        stock = yf.Ticker(symbol)
        history = stock.history(period='max')
        if len(history) == 0:
            continue
        # Find the earliest start date
        start_date = history.index.min().strftime('%Y-%m-%d')
        # Find the dates of the first and last weekday in each week
        weekdays = history.groupby(pd.Grouper(freq='W-MON'))['Close'].apply(lambda x: (x.index.min().strftime('%Y-%m-%d'), x.index.max().strftime('%Y-%m-%d')))
        for start_date, end_date in weekdays:
            week_history = history.loc[start_date:end_date]
            start_price = week_history['Open'][0]
            end_price = week_history['Close'][-1]
            dividends = week_history['Dividends'].sum()
            capital_gain = (end_price - start_price - dividends) / start_price
            end_value = ((start_price * capital_gain) + (start_price * dividends))
            total_return = (end_price - start_price) / start_price
            weekly_returns.append({'symbol': symbol, 'start_date': week_history.index[0].strftime('%Y-%m-%d'), 'end_date': week_history.index[-1].strftime('%Y-%m-%d'), 'start_price': start_price, 'end_price': end_price, 'end_value': end_value, 'total_return': total_return, 'dividend_return': dividends/start_price, 'capital_gain_return': capital_gain})
    
    # Write results to CSV file
    with open(output_file, 'w', newline='') as csvfile:
        fieldnames = ['symbol', 'start_date', 'end_date', 'start_price', 'end_price', 'end_value', 'total_return', 'capital_gain_return', 'dividend_return']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in weekly_returns:
            writer.writerow(row)

# %%
tickers = tickers
output_file = 'weekly_stock_returns.csv'

calculate_weekly_returns(tickers, output_file)

# %% [markdown]
# ### **Get Returns**

# %%
import pandas as pd
import yfinance as yf
import csv
import datetime

def calculate_returns(start_dates, ticker_symbols, output_file):
    """
    Calculates the total return of one or more stocks over a specified period of time,
    breaking out the returns into dividends and capital gains.

    :param start_dates: A list of start dates in YYYY-MM-DD format.
    :param ticker_symbols: A list of ticker symbols to calculate returns for.
    :param output_file: The name of the CSV file to output results to.
    :return: A list of dictionaries, where each dictionary represents the returns for a single stock.
    """
    today = datetime.date.today().strftime('%Y-%m-%d')
    
    returns = []
    for symbol in ticker_symbols:
        for start_date in start_dates:
            stock = yf.Ticker(symbol)
            history = stock.history(start=start_date, end=today)
            if len(history) == 0:
                continue
            start_price = history['Close'][0]
            end_price = history['Close'][-1]
            dividends = history['Dividends'].sum()
            capital_gain = (end_price - start_price - dividends) / start_price
            total_return = (end_price - start_price) / start_price
            returns.append({'symbol': symbol, 'start_date': start_date, 'total_return': total_return, 'dividend_return': dividends/start_price, 'capital_gain_return': capital_gain})
    
    # Write results to CSV file
    with open(output_file, 'w', newline='') as csvfile:
        fieldnames = ['symbol', 'start_date', 'total_return', 'dividend_return', 'capital_gain_return']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in returns:
            writer.writerow(row)

# %%
import csv

# Set the tickers and start dates
tickers = tickers
start_dates = ['2013-04-25', '2003-04-25', '2018-04-25', '2022-04-25']

# Calculate the returns for all tickers at the specified start date
calculate_returns(start_dates, tickers, 'returns.csv')

# %%
# import jinja2
# raw_query = """
#     select 
#     symbol,
#     start_date,
#     ROUND(total_return, 2) as total_return,
#     ROUND(dividend_return, 2) as dividend_return,
#     ROUND(capital_gain_return, 2) as capital_gain_return
#     
#     from "returns.csv";
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %% [markdown]
# ## **Get fundamentals data**

# %%
import pandas as pd
import csv
import os
import requests
import glob
import io


api_key = "a726d5acabd86910ef2749315f5eaa86"

# %% [markdown]
# #### Ratios

# %%
# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/ratios/{}?datatype=csv&apikey=90b7ef69ff8550aabc5480eccc68a854"

# define a list of tickers
tickers = tickers

# define an empty dictionary to store the dataframes for each ticker
ticker_dataframes = {}

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))
    
    # Remove the 'label' column
    #df.drop('calendarYear', axis=1, inplace=True)

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("ratiosFY.csv", index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
ratios = pd.read_csv('ratiosFY.csv')


# Handle Non-finite Values:
# ratios['averageInventory'] = ratios['averageInventory'].fillna(0).astype(int)

# Drop the 'calendarYear' column if it exists
if 'CALENDARYEAR' in ratios.columns:
    ratios.drop(columns=['CALENDARYEAR'], inplace=True)

# Explicitly set the 'DATE' column as datetime64[ns]
ratios = pd.DataFrame({
    'SYMBOL': ratios['symbol'].astype(str),
    'DATE': pd.to_datetime(ratios['date'], errors='coerce'),
    'PERIOD': ratios['period'].astype(str),
    'CURRENTRATIO': ratios['currentRatio'].astype(float),
    'QUICKRATIO': ratios['quickRatio'].astype(float),
    'CASHRATIO': ratios['cashRatio'].astype(float),
    'DAYSOFSALESOUTSTANDING': ratios['daysOfSalesOutstanding'].astype(float),
    'DAYSOFINVENTORYOUTSTANDING': ratios['daysOfInventoryOutstanding'].astype(float),
    'OPERATINGCYCLE': ratios['operatingCycle'].astype(float),
    'DAYSOFPAYABLESOUTSTANDING': ratios['daysOfPayablesOutstanding'].astype(float),
    'CASHCONVERSIONCYCLE': ratios['cashConversionCycle'].astype(float),
    'GROSSPROFITMARGIN': ratios['grossProfitMargin'].astype(float),
    'OPERATINGPROFITMARGIN': ratios['operatingProfitMargin'].astype(float),
    'PRETAXPROFITMARGIN': ratios['pretaxProfitMargin'].astype(float),
    'NETPROFITMARGIN': ratios['netProfitMargin'].astype(float),
    'EFFECTIVETAXRATE': ratios['effectiveTaxRate'].astype(float),
    'RETURNONASSETS': ratios['returnOnAssets'].astype(float),
    'RETURNONEQUITY': ratios['returnOnEquity'].astype(float),
    'RETURNONCAPITALEMPLOYED': ratios['returnOnCapitalEmployed'].astype(float),
    'NETINCOMEPEREBT': ratios['netIncomePerEBT'].astype(float),
    'EBTPEREBIT': ratios['ebtPerEbit'].astype(float),
    'EBITPERREVENUE': ratios['ebitPerRevenue'].astype(float),
    'DEBTRATIO': ratios['debtRatio'].astype(float),
    'DEBTEQUITYRATIO': ratios['debtEquityRatio'].astype(float),
    'LONGTERMDEBTTOCAPITALIZATION': ratios['longTermDebtToCapitalization'].astype(float),
    'TOTALDEBTTOCAPITALIZATION': ratios['totalDebtToCapitalization'].astype(float),
    'INTERESTCOVERAGE': ratios['interestCoverage'].astype(float),
    'CASHFLOWTODEBTRATIO': ratios['cashFlowToDebtRatio'].astype(float),
    'COMPANYEQUITYMULTIPLIER': ratios['companyEquityMultiplier'].astype(float),
    'RECEIVABLESTURNOVER': ratios['receivablesTurnover'].astype(float),
    'PAYABLESTURNOVER': ratios['payablesTurnover'].astype(float),
    'INVENTORYTURNOVER': ratios['inventoryTurnover'].astype(float),
    'FIXEDASSETTURNOVER': ratios['fixedAssetTurnover'].astype(float),
    'ASSETTURNOVER': ratios['assetTurnover'].astype(float),
    'OPERATINGCASHFLOWPERSHARE': ratios['operatingCashFlowPerShare'].astype(float),
    'FREECASHFLOWPERSHARE': ratios['freeCashFlowPerShare'].astype(float),
    'CASHPERSHARE': ratios['cashPerShare'].astype(float),
    'PAYOUTRATIO': ratios['payoutRatio'].astype(float),
    'OPERATINGCASHFLOWSALESRATIO': ratios['operatingCashFlowSalesRatio'].astype(float),
    'FREECASHFLOWOPERATINGCASHFLOWRATIO': ratios['freeCashFlowOperatingCashFlowRatio'].astype(float),
    'CASHFLOWCOVERAGERATIOS': ratios['cashFlowCoverageRatios'].astype(float),
    'SHORTTERMCOVERAGERATIOS': ratios['shortTermCoverageRatios'].astype(float),
    'CAPITALEXPENDITURECOVERAGERATIO': ratios['capitalExpenditureCoverageRatio'].astype(float),
    'DIVIDENDPAIDANDCAPEXCOVERAGERATIO': ratios['dividendPaidAndCapexCoverageRatio'].astype(float),
    'DIVIDENDPAYOUTRATIO': ratios['dividendPayoutRatio'].astype(float),
    'PRICEBOOKVALUERATIO': ratios['priceBookValueRatio'].astype(float),
    'PRICETOBOOKRATIO': ratios['priceToBookRatio'].astype(float),
    'PRICETOSALESRATIO': ratios['priceToSalesRatio'].astype(float),
    'PRICEEARNINGSRATIO': ratios['priceEarningsRatio'].astype(float),
    'PRICETOFREECASHFLOWSRATIO': ratios['priceToFreeCashFlowsRatio'].astype(float),
    'PRICETOOPERATINGCASHFLOWSRATIO': ratios['priceToOperatingCashFlowsRatio'].astype(float),
    'PRICECASHFLOWRATIO': ratios['priceCashFlowRatio'].astype(float),
    'PRICEEARNINGSTOGROWTHRATIO': ratios['priceEarningsToGrowthRatio'].astype(float),
    'PRICESALESRATIO': ratios['priceSalesRatio'].astype(float),
    'DIVIDENDYIELD': ratios['dividendYield'].astype(float),
    'ENTERPRISEVALUEMULTIPLE': ratios['enterpriseValueMultiple'].astype(float),
    'PRICEFAIRVALUE': ratios['priceFairValue'].astype(float),
})

ratios.columns = ratios.columns.str.upper()


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'ratios'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.ratios'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


client.load_table_from_dataframe(
    ratios, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=9dd0f12d-69cb-42d0-b705-6a439f906d88>

# %%
job_id = '9dd0f12d-69cb-42d0-b705-6a439f906d88'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %%
# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/ratios/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a list of tickers
tickers = tickers

# define an empty dictionary to store the dataframes for each ticker
ticker_dataframes = {}

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))
    
    # Remove the 'label' column
    #df.drop('calendarYear', axis=1, inplace=True)

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("ratios_quarterly.csv", index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
ratios = pd.read_csv('ratios_quarterly.csv')


# Handle Non-finite Values:
# ratios['averageInventory'] = ratios['averageInventory'].fillna(0).astype(int)

# Drop the 'calendarYear' column if it exists
if 'CALENDARYEAR' in ratios.columns:
    ratios.drop(columns=['CALENDARYEAR'], inplace=True)

# Explicitly set the 'DATE' column as datetime64[ns]
ratios = pd.DataFrame({
    'SYMBOL': ratios['symbol'].astype(str),
    'DATE': pd.to_datetime(ratios['date'], errors='coerce'),
    'PERIOD': ratios['period'].astype(str),
    'CURRENTRATIO': ratios['currentRatio'].astype(float),
    'QUICKRATIO': ratios['quickRatio'].astype(float),
    'CASHRATIO': ratios['cashRatio'].astype(float),
    'DAYSOFSALESOUTSTANDING': ratios['daysOfSalesOutstanding'].astype(float),
    'DAYSOFINVENTORYOUTSTANDING': ratios['daysOfInventoryOutstanding'].astype(float),
    'OPERATINGCYCLE': ratios['operatingCycle'].astype(float),
    'DAYSOFPAYABLESOUTSTANDING': ratios['daysOfPayablesOutstanding'].astype(float),
    'CASHCONVERSIONCYCLE': ratios['cashConversionCycle'].astype(float),
    'GROSSPROFITMARGIN': ratios['grossProfitMargin'].astype(float),
    'OPERATINGPROFITMARGIN': ratios['operatingProfitMargin'].astype(float),
    'PRETAXPROFITMARGIN': ratios['pretaxProfitMargin'].astype(float),
    'NETPROFITMARGIN': ratios['netProfitMargin'].astype(float),
    'EFFECTIVETAXRATE': ratios['effectiveTaxRate'].astype(float),
    'RETURNONASSETS': ratios['returnOnAssets'].astype(float),
    'RETURNONEQUITY': ratios['returnOnEquity'].astype(float),
    'RETURNONCAPITALEMPLOYED': ratios['returnOnCapitalEmployed'].astype(float),
    'NETINCOMEPEREBT': ratios['netIncomePerEBT'].astype(float),
    'EBTPEREBIT': ratios['ebtPerEbit'].astype(float),
    'EBITPERREVENUE': ratios['ebitPerRevenue'].astype(float),
    'DEBTRATIO': ratios['debtRatio'].astype(float),
    'DEBTEQUITYRATIO': ratios['debtEquityRatio'].astype(float),
    'LONGTERMDEBTTOCAPITALIZATION': ratios['longTermDebtToCapitalization'].astype(float),
    'TOTALDEBTTOCAPITALIZATION': ratios['totalDebtToCapitalization'].astype(float),
    'INTERESTCOVERAGE': ratios['interestCoverage'].astype(float),
    'CASHFLOWTODEBTRATIO': ratios['cashFlowToDebtRatio'].astype(float),
    'COMPANYEQUITYMULTIPLIER': ratios['companyEquityMultiplier'].astype(float),
    'RECEIVABLESTURNOVER': ratios['receivablesTurnover'].astype(float),
    'PAYABLESTURNOVER': ratios['payablesTurnover'].astype(float),
    'INVENTORYTURNOVER': ratios['inventoryTurnover'].astype(float),
    'FIXEDASSETTURNOVER': ratios['fixedAssetTurnover'].astype(float),
    'ASSETTURNOVER': ratios['assetTurnover'].astype(float),
    'OPERATINGCASHFLOWPERSHARE': ratios['operatingCashFlowPerShare'].astype(float),
    'FREECASHFLOWPERSHARE': ratios['freeCashFlowPerShare'].astype(float),
    'CASHPERSHARE': ratios['cashPerShare'].astype(float),
    'PAYOUTRATIO': ratios['payoutRatio'].astype(float),
    'OPERATINGCASHFLOWSALESRATIO': ratios['operatingCashFlowSalesRatio'].astype(float),
    'FREECASHFLOWOPERATINGCASHFLOWRATIO': ratios['freeCashFlowOperatingCashFlowRatio'].astype(float),
    'CASHFLOWCOVERAGERATIOS': ratios['cashFlowCoverageRatios'].astype(float),
    'SHORTTERMCOVERAGERATIOS': ratios['shortTermCoverageRatios'].astype(float),
    'CAPITALEXPENDITURECOVERAGERATIO': ratios['capitalExpenditureCoverageRatio'].astype(float),
    'DIVIDENDPAIDANDCAPEXCOVERAGERATIO': ratios['dividendPaidAndCapexCoverageRatio'].astype(float),
    'DIVIDENDPAYOUTRATIO': ratios['dividendPayoutRatio'].astype(float),
    'PRICEBOOKVALUERATIO': ratios['priceBookValueRatio'].astype(float),
    'PRICETOBOOKRATIO': ratios['priceToBookRatio'].astype(float),
    'PRICETOSALESRATIO': ratios['priceToSalesRatio'].astype(float),
    'PRICEEARNINGSRATIO': ratios['priceEarningsRatio'].astype(float),
    'PRICETOFREECASHFLOWSRATIO': ratios['priceToFreeCashFlowsRatio'].astype(float),
    'PRICETOOPERATINGCASHFLOWSRATIO': ratios['priceToOperatingCashFlowsRatio'].astype(float),
    'PRICECASHFLOWRATIO': ratios['priceCashFlowRatio'].astype(float),
    'PRICEEARNINGSTOGROWTHRATIO': ratios['priceEarningsToGrowthRatio'].astype(float),
    'PRICESALESRATIO': ratios['priceSalesRatio'].astype(float),
    'DIVIDENDYIELD': ratios['dividendYield'].astype(float),
    'ENTERPRISEVALUEMULTIPLE': ratios['enterpriseValueMultiple'].astype(float),
    'PRICEFAIRVALUE': ratios['priceFairValue'].astype(float),
})

ratios.columns = ratios.columns.str.upper()


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'ratios'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.ratios'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


client.load_table_from_dataframe(
    ratios, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=c2e70840-7ebd-497f-8d75-2879cc91ebd0>

# %%
job_id = 'c2e70840-7ebd-497f-8d75-2879cc91ebd0'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# #### Key Metrics

# %%
# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/key-metrics/{}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("metricsFY.csv", index=False)

# %%
import pandas as pd

# Read the CSV file using pandas
df = pd.read_csv('metricsFY.csv')

# Define the DW table columns
desired_columns = [
    "symbol",
    "date",
    "period",
    "revenuePerShare",
    "netIncomePerShare",
    "operatingCashFlowPerShare",
    "freeCashFlowPerShare",
    "cashPerShare",
    "bookValuePerShare",
    "tangibleBookValuePerShare",
    "peRatio",
    "priceToSalesRatio",
    "pfcfRatio",
    "pbRatio",
    "evToSales",
    "evToOperatingCashFlow",
    "evToFreeCashFlow",
    "freeCashFlowYield",
    "debtToEquity",
    "debtToAssets",
    "currentRatio",
    "dividendYield",
    "salesGeneralAndAdministrativeToRevenue",
    "researchAndDdevelopementToRevenue",
    "intangiblesToTotalAssets",
    "capexToOperatingCashFlow",
    "capexToRevenue",
    "stockBasedCompensationToRevenue",
    "roic",
    "returnOnTangibleAssets",
    "averageInventory",
    "daysSalesOutstanding",
    "daysOfInventoryOnHand",
    "inventoryTurnover",
    "roe",
    "capexPerShare"
]

# Keep only the desired columns
df = df[desired_columns]

# Save the resulting DataFrame to a new CSV file
df.to_csv('metricsFY.csv', index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
key_metrics = pd.read_csv('metricsFY.csv')


# Handle Non-finite Values:
key_metrics['averageInventory'] = key_metrics['averageInventory'].fillna(0).astype(int)
key_metrics['daysSalesOutstanding'] = key_metrics['daysSalesOutstanding'].fillna(0).astype(int)
key_metrics['daysOfInventoryOnHand'] = key_metrics['daysOfInventoryOnHand'].fillna(0).astype(int)


# Explicitly set the 'DATE' column as datetime64[ns]
key_metrics = pd.DataFrame({
    'SYMBOL': key_metrics['symbol'].astype(str),
    'DATE': pd.to_datetime(key_metrics['date'], errors='coerce'),
    'PERIOD': key_metrics['period'].astype(str),
    'REVENUEPERSHARE': key_metrics['revenuePerShare'].astype(float),
    'NETINCOMEPERSHARE': key_metrics['netIncomePerShare'].astype(float),
    'OPERATINGCASHFLOWPERSHARE': key_metrics['operatingCashFlowPerShare'].astype(float),
    'FREECASHFLOWPERSHARE': key_metrics['freeCashFlowPerShare'].astype(float),
    'CASHPERSHARE': key_metrics['cashPerShare'].astype(float),
    'BOOKVALUEPERSHARE': key_metrics['bookValuePerShare'].astype(float),
    'TANGIBLEBOOKVALUEPERSHARE': key_metrics['tangibleBookValuePerShare'].astype(float),
    'PERATIO': key_metrics['peRatio'].astype(float),
    'PRICETOSALESRATIO': key_metrics['priceToSalesRatio'].astype(float),
    'PFCFRATIO': key_metrics['pfcfRatio'].astype(float),
    'PBRATIO': key_metrics['pbRatio'].astype(float),
    'EVTOSALES': key_metrics['evToSales'].astype(float),
    'EVTOOPERATINGCASHFLOW': key_metrics['evToOperatingCashFlow'].astype(float),
    'EVTOFREECASHFLOW': key_metrics['evToFreeCashFlow'].astype(float),
    'FREECASHFLOWYIELD': key_metrics['freeCashFlowYield'].astype(float),
    'DEBTTOEQUITY': key_metrics['debtToEquity'].astype(float),
    'DEBTTOASSETS': key_metrics['debtToAssets'].astype(float),
    'CURRENTRATIO': key_metrics['currentRatio'].astype(float),
    'DIVIDENDYIELD': key_metrics['dividendYield'].astype(float),
    'SALESGENERALANDADMINISTRATIVETOREVENUE': key_metrics['salesGeneralAndAdministrativeToRevenue'].astype(float),
    'RESEARCHANDDEVELOPMENTTOREVENUE': key_metrics['researchAndDdevelopementToRevenue'].astype(float),
    'INTANGIBLESTOTOTALASSETS': key_metrics['intangiblesToTotalAssets'].astype(float),
    'CAPEXTOOPERATINGCASHFLOW': key_metrics['capexToOperatingCashFlow'].astype(float),
    'CAPEXTOREVENUE': key_metrics['capexToRevenue'].astype(float),
    'STOCKBASEDCOMPENSATIONTOREVENUE': key_metrics['stockBasedCompensationToRevenue'].astype(float),
    'ROIC': key_metrics['roic'].astype(float),
    'RETURNONTANGIBLEASSETS': key_metrics['returnOnTangibleAssets'].astype(float),
    'AVERAGEINVENTORY': key_metrics['averageInventory'].astype(int),
    'DAYSSALESOUTSTANDING': key_metrics['daysSalesOutstanding'].astype(int),
    'DAYSOFINVENTORYONHAND': key_metrics['daysOfInventoryOnHand'].astype(int),
    'INVENTORYTURNOVER': key_metrics['inventoryTurnover'].astype(float),
    'ROE': key_metrics['roe'].astype(float),
    'CAPEXPERSHARE': key_metrics['capexPerShare'].astype(float),
})

# Check if the column exists before renaming
old_column_name = 'researchAndDdevelopementToRevenue'
new_column_name = 'researchAndDevelopementToRevenue'

if old_column_name in key_metrics.columns:
    key_metrics.rename(columns={old_column_name: new_column_name}, inplace=True)


key_metrics.columns = key_metrics.columns.str.upper()


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'key_metrics'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.key_metrics'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


client.load_table_from_dataframe(
    key_metrics, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=bcfff2f4-59a3-4e04-ae8e-2611f539f067>

# %%
job_id = 'bcfff2f4-59a3-4e04-ae8e-2611f539f067'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %%
# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/key-metrics/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("metrics_quarterly.csv", index=False)

# %%
import pandas as pd

# Read the CSV file using pandas
df = pd.read_csv('metrics_quarterly.csv')

# Define the DW table columns
desired_columns = [
    "symbol",
    "date",
    "period",
    "revenuePerShare",
    "netIncomePerShare",
    "operatingCashFlowPerShare",
    "freeCashFlowPerShare",
    "cashPerShare",
    "bookValuePerShare",
    "tangibleBookValuePerShare",
    "peRatio",
    "priceToSalesRatio",
    "pfcfRatio",
    "pbRatio",
    "evToSales",
    "evToOperatingCashFlow",
    "evToFreeCashFlow",
    "freeCashFlowYield",
    "debtToEquity",
    "debtToAssets",
    "currentRatio",
    "dividendYield",
    "salesGeneralAndAdministrativeToRevenue",
    "researchAndDdevelopementToRevenue",
    "intangiblesToTotalAssets",
    "capexToOperatingCashFlow",
    "capexToRevenue",
    "stockBasedCompensationToRevenue",
    "roic",
    "returnOnTangibleAssets",
    "averageInventory",
    "daysSalesOutstanding",
    "daysOfInventoryOnHand",
    "inventoryTurnover",
    "roe",
    "capexPerShare"
]

# Keep only the desired columns
df = df[desired_columns]

# Save the resulting DataFrame to a new CSV file
df.to_csv('metrics_quarterly.csv', index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
key_metrics = pd.read_csv('metrics_quarterly.csv')


# Handle Non-finite Values:
key_metrics['averageInventory'] = key_metrics['averageInventory'].fillna(0).astype(int)
key_metrics['daysSalesOutstanding'] = key_metrics['daysSalesOutstanding'].fillna(0).astype(int)
key_metrics['daysOfInventoryOnHand'] = key_metrics['daysOfInventoryOnHand'].fillna(0).astype(int)


# Explicitly set the 'DATE' column as datetime64[ns]
key_metrics = pd.DataFrame({
    'SYMBOL': key_metrics['symbol'].astype(str),
    'DATE': pd.to_datetime(key_metrics['date'], errors='coerce'),
    'PERIOD': key_metrics['period'].astype(str),
    'REVENUEPERSHARE': key_metrics['revenuePerShare'].astype(float),
    'NETINCOMEPERSHARE': key_metrics['netIncomePerShare'].astype(float),
    'OPERATINGCASHFLOWPERSHARE': key_metrics['operatingCashFlowPerShare'].astype(float),
    'FREECASHFLOWPERSHARE': key_metrics['freeCashFlowPerShare'].astype(float),
    'CASHPERSHARE': key_metrics['cashPerShare'].astype(float),
    'BOOKVALUEPERSHARE': key_metrics['bookValuePerShare'].astype(float),
    'TANGIBLEBOOKVALUEPERSHARE': key_metrics['tangibleBookValuePerShare'].astype(float),
    'PERATIO': key_metrics['peRatio'].astype(float),
    'PRICETOSALESRATIO': key_metrics['priceToSalesRatio'].astype(float),
    'PFCFRATIO': key_metrics['pfcfRatio'].astype(float),
    'PBRATIO': key_metrics['pbRatio'].astype(float),
    'EVTOSALES': key_metrics['evToSales'].astype(float),
    'EVTOOPERATINGCASHFLOW': key_metrics['evToOperatingCashFlow'].astype(float),
    'EVTOFREECASHFLOW': key_metrics['evToFreeCashFlow'].astype(float),
    'FREECASHFLOWYIELD': key_metrics['freeCashFlowYield'].astype(float),
    'DEBTTOEQUITY': key_metrics['debtToEquity'].astype(float),
    'DEBTTOASSETS': key_metrics['debtToAssets'].astype(float),
    'CURRENTRATIO': key_metrics['currentRatio'].astype(float),
    'DIVIDENDYIELD': key_metrics['dividendYield'].astype(float),
    'SALESGENERALANDADMINISTRATIVETOREVENUE': key_metrics['salesGeneralAndAdministrativeToRevenue'].astype(float),
    'RESEARCHANDDEVELOPMENTTOREVENUE': key_metrics['researchAndDdevelopementToRevenue'].astype(float),
    'INTANGIBLESTOTOTALASSETS': key_metrics['intangiblesToTotalAssets'].astype(float),
    'CAPEXTOOPERATINGCASHFLOW': key_metrics['capexToOperatingCashFlow'].astype(float),
    'CAPEXTOREVENUE': key_metrics['capexToRevenue'].astype(float),
    'STOCKBASEDCOMPENSATIONTOREVENUE': key_metrics['stockBasedCompensationToRevenue'].astype(float),
    'ROIC': key_metrics['roic'].astype(float),
    'RETURNONTANGIBLEASSETS': key_metrics['returnOnTangibleAssets'].astype(float),
    'AVERAGEINVENTORY': key_metrics['averageInventory'].astype(int),
    'DAYSSALESOUTSTANDING': key_metrics['daysSalesOutstanding'].astype(int),
    'DAYSOFINVENTORYONHAND': key_metrics['daysOfInventoryOnHand'].astype(int),
    'INVENTORYTURNOVER': key_metrics['inventoryTurnover'].astype(float),
    'ROE': key_metrics['roe'].astype(float),
    'CAPEXPERSHARE': key_metrics['capexPerShare'].astype(float),
})

# Check if the column exists before renaming
old_column_name = 'researchAndDdevelopementToRevenue'
new_column_name = 'researchAndDevelopementToRevenue'

if old_column_name in key_metrics.columns:
    key_metrics.rename(columns={old_column_name: new_column_name}, inplace=True)


key_metrics.columns = key_metrics.columns.str.upper()


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'key_metrics'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.key_metrics'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


client.load_table_from_dataframe(
    key_metrics, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=75193c05-ec54-4697-9925-e9dd8c731de8>

# %%
job_id = '75193c05-ec54-4697-9925-e9dd8c731de8'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Income Statements

# %%
import requests
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/income-statement-shorten/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.content.decode('utf-8-sig')

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
income_statements_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
income_statements_df.to_csv("income_statements_quarterly.csv", index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
income_statements_quarterly = pd.read_csv('income_statements_quarterly.csv')

# Drop the 'CALENDARYEAR' column if it exists
if 'CALENDARYEAR' in income_statements_quarterly.columns:
    income_statements_quarterly.drop(columns=['CALENDARYEAR'], inplace=True)

# Explicitly set the data types for columns
income_statements_quarterly = pd.DataFrame({
    'DATE': pd.to_datetime(income_statements_quarterly['date'], errors='coerce'),
    'SYMBOL': income_statements_quarterly['symbol'].astype(str),
    'REPORTEDCURRENCY': income_statements_quarterly['reportedCurrency'].astype(str),
    'CIK': income_statements_quarterly['cik'].astype(int),
    'FILLINGDATE': pd.to_datetime(income_statements_quarterly['fillingDate'], errors='coerce'),
    'ACCEPTEDDATE': pd.to_datetime(income_statements_quarterly['acceptedDate'], errors='coerce'),
    'CALENDARYEAR': income_statements_quarterly['calendarYear'].astype(int),
    'PERIOD': income_statements_quarterly['period'].astype(str),
    'REVENUE': income_statements_quarterly['revenue'].astype(int),
    'COSTOFREVENUE': income_statements_quarterly['costOfRevenue'].astype(int),
    'GROSSPROFIT': income_statements_quarterly['grossProfit'].astype(int),
    'GROSSPROFITRATIO': income_statements_quarterly['grossProfitRatio'].astype(float),
    'RESEARCHANDDEVELOPMENTEXPENSES': income_statements_quarterly['researchAndDevelopmentExpenses'].astype(int),
    'GENERALANDADMINISTRATIVEEXPENSES': income_statements_quarterly['generalAndAdministrativeExpenses'].astype(int),
    'SELLINGANDMARKETINGEXPENSES': income_statements_quarterly['sellingAndMarketingExpenses'].astype(int),
    'SELLINGGENERALANDADMINISTRATIVEEXPENSES': income_statements_quarterly['sellingGeneralAndAdministrativeExpenses'].astype(int),
    'OTHEREXPENSES': income_statements_quarterly['otherExpenses'].astype(int),
    'OPERATINGEXPENSES': income_statements_quarterly['operatingExpenses'].astype(int),
    'COSTANDEXPENSES': income_statements_quarterly['costAndExpenses'].astype(int),
    'INTERESTINCOME': income_statements_quarterly['interestIncome'].astype(int),
    'INTERESTEXPENSE': income_statements_quarterly['interestExpense'].astype(int),
    'DEPRECIATIONANDAMORTIZATION': income_statements_quarterly['depreciationAndAmortization'].astype(int),
    'EBITDA': income_statements_quarterly['ebitda'].astype(int),
    'EBITDARATIO': income_statements_quarterly['ebitdaratio'].astype(float),
    'OPERATINGINCOME': income_statements_quarterly['operatingIncome'].astype(int),
    'OPERATINGINCOMERATIO': income_statements_quarterly['operatingIncomeRatio'].astype(float),
    'TOTALOTHERINCOMEEXPENSESNET': income_statements_quarterly['totalOtherIncomeExpensesNet'].astype(int),
    'INCOMEBEFORETAX': income_statements_quarterly['incomeBeforeTax'].astype(int),
    'INCOMEBEFORETAXRATIO': income_statements_quarterly['incomeBeforeTaxRatio'].astype(float),
    'INCOMETAXEXPENSE': income_statements_quarterly['incomeTaxExpense'].astype(int),
    'NETINCOME': income_statements_quarterly['netIncome'].astype(int),
    'NETINCOMERATIO': income_statements_quarterly['netIncomeRatio'].astype(float),
    'EPS': income_statements_quarterly['eps'].astype(float),
    'EPSDILUTED': income_statements_quarterly['epsdiluted'].astype(float),
    'WEIGHTEDAVERAGESHSOUT': income_statements_quarterly['weightedAverageShsOut'].astype(int),
    'WEIGHTEDAVERAGESHSOUTDIL': income_statements_quarterly['weightedAverageShsOutDil'].astype(int),
    'LINK': income_statements_quarterly['link'].astype(str),
    'FINALLINK': income_statements_quarterly['finalLink'].astype(str),
    'TICKER': income_statements_quarterly['Ticker'].astype(str),
})

project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'income_statements'

# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = f'{project_id}.{dataset_id}.{table_name}'

# Write the DataFrame to BigQuery with schema auto-detection
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",
)

client.load_table_from_dataframe(
    income_statements_quarterly, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=aebcfa07-f1d9-41e6-aeba-573a4c1c2fe8>

# %%
job_id = 'aebcfa07-f1d9-41e6-aeba-573a4c1c2fe8'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Balance Sheets

# %%
import requests
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/balance-sheet-statement-shorten/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.content.decode('utf-8-sig')

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # Remove the 'label' column
    # df.drop('deferrredTaxLiabilitiesNonCurrent', axis=1, inplace=True)

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
balance_sheets_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
balance_sheets_df.to_csv("balance_sheets.csv", index=False)

# %%
# Get CSV column names
df = pd.read_csv('balance_sheets.csv') 
csv_cols = df.columns

snowflake_cols = ['date', 'symbol','reportedCurrency','cik','fillingDate', 'acceptedDate',  
                  'calendarYear', 'period', 'cashAndCashEquivalents',  
                  'shortTermInvestments', 'cashAndShortTermInvestments',  
                  'netReceivables', 'inventory', 'otherCurrentAssets',  
                  'totalCurrentAssets', 'propertyPlantEquipmentNet', 'goodwill',  
                  'intangibleAssets', 'goodwillAndIntangibleAssets',  
                  'longTermInvestments', 'taxAssets',  
                  'otherNonCurrentAssets', 'totalNonCurrentAssets', 'otherAssets', 
                  'totalAssets', 'accountPayables', 'shortTermDebt', 'taxPayables',  
                  'deferredRevenue', 'otherCurrentLiabilities','totalCurrentLiabilities',
                  'longTermDebt', 'deferredRevenueNonCurrent',  
                  'deferredTaxLiabilitiesNonCurrent', 'otherNonCurrentLiabilities',
                  'totalNonCurrentLiabilities', 'otherLiabilities',
                  'capitalLeaseObligations','totalLiabilities', 'preferredStock',
                  'commonStock', 'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
                  'othertotalStockholdersEquity','totalStockholdersEquity', 'totalEquity',
                  'totalLiabilitiesAndStockholdersEquity', 'minorityInterest', 'totalLiabilitiesAndTotalEquity',
                  'totalInvestments', 'totalDebt', 'netDebt', 'link', 'finalLink','Ticker']

# Identify column name mapping 
mapping = {csv_col: snowflake_col for csv_col, snowflake_col in zip(csv_cols, snowflake_cols)}

# Reorder columns with mapping 
df = df[snowflake_cols]

# Export to CSV 
df.to_csv('balance_sheets_formatted.csv', index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
balance_sheets = pd.read_csv('balance_sheets_formatted.csv')

# Drop the 'CALENDARYEAR' column if it exists
if 'CALENDARYEAR' in balance_sheets.columns:
    balance_sheets.drop(columns=['CALENDARYEAR'], inplace=True)

# Drop the 'deferredTaxLiabilitiesNonCurrent' column
if 'deferredTaxLiabilitiesNonCurrent' in balance_sheets.columns:
    balance_sheets.drop(columns=['deferredTaxLiabilitiesNonCurrent'], inplace=True)

# Handle Non-finite Values:
balance_sheets['TOTALDEBT'] = balance_sheets['totalDebt'].fillna(0).astype(int)


# Explicitly set the data types for columns
balance_sheets = pd.DataFrame({
    'DATE': pd.to_datetime(balance_sheets['date']),
    'SYMBOL': balance_sheets['symbol'].astype(str),
    'REPORTEDCURRENCY': balance_sheets['reportedCurrency'].astype(str),
    'CIK': balance_sheets['cik'].astype('int64'),
    'FILINGDATE': pd.to_datetime(balance_sheets['fillingDate']),
    'ACCEPTEDDATE': pd.to_datetime(balance_sheets['acceptedDate']),
    'CALENDARYEAR': balance_sheets['calendarYear'].astype('int64'),
    'PERIOD': balance_sheets['period'].astype(str),
    'CASHANDCASHEQUIVALENTS': balance_sheets['cashAndCashEquivalents'].astype('int64'),
    'SHORTTERMINVESTMENTS': balance_sheets['shortTermInvestments'].astype('int64'),
    'CASHANDSHORTTERMINVESTMENTS': balance_sheets['cashAndShortTermInvestments'].astype('int64'),
    'NETRECEIVABLES': balance_sheets['netReceivables'].astype('int64'),
    'INVENTORY': balance_sheets['inventory'].astype('int64'),
    'OTHERCURRENTASSETS': balance_sheets['otherCurrentAssets'].astype('int64'),
    'TOTALCURRENTASSETS': balance_sheets['totalCurrentAssets'].astype('int64'),
    'PROPERTYPLANTEQUIPMENTNET': balance_sheets['propertyPlantEquipmentNet'].astype('int64'),
    'GOODWILL': balance_sheets['goodwill'].astype('int64'),
    'INTANGIBLEASSETS': balance_sheets['intangibleAssets'].astype('int64'),
    'GOODWILLANDINTANGIBLEASSETS': balance_sheets['goodwillAndIntangibleAssets'].astype('int64'),
    'LONGTERMINVESTMENTS': balance_sheets['longTermInvestments'].astype('int64'),
    'TAXASSETS': balance_sheets['taxAssets'].astype('int64'),
    'OTHERNONCURRENTASSETS': balance_sheets['otherNonCurrentAssets'].astype('int64'),
    'TOTALNONCURRENTASSETS': balance_sheets['totalNonCurrentAssets'].astype('int64'),
    'OTHERASSETS': balance_sheets['otherAssets'].astype('int64'),
    'TOTALASSETS': balance_sheets['totalAssets'].astype('int64'),
    'ACCOUNTPAYABLES': balance_sheets['accountPayables'].astype('int64'),
    'SHORTTERMDEBT': balance_sheets['shortTermDebt'].astype('int64'),
    'TAXPAYABLES': balance_sheets['taxPayables'].astype('int64'),
    'DEFERREDREVENUE': balance_sheets['deferredRevenue'].astype('int64'),
    'OTHERCURRENTLIABILITIES': balance_sheets['otherCurrentLiabilities'].astype('int64'),
    'TOTALCURRENTLIABILITIES': balance_sheets['totalCurrentLiabilities'].astype('int64'),
    'LONGTERMDEBT': balance_sheets['longTermDebt'].astype('int64'),
    'DEFERREDREVENUENONCURRENT': balance_sheets['deferredRevenueNonCurrent'].astype('int64'),
    'OTHERNONCURRENTLIABILITIES': balance_sheets['otherNonCurrentLiabilities'].astype('int64'),
    'TOTALNONCURRENTLIABILITIES': balance_sheets['totalNonCurrentLiabilities'].astype('int64'),
    'OTHERLIABILITIES': balance_sheets['otherLiabilities'].astype('int64'),
    'CAPITALLEASEOBLIGATIONS': balance_sheets['capitalLeaseObligations'].astype('int64'),
    'TOTALLIABILITIES': balance_sheets['totalLiabilities'].astype('int64'),
    'PREFERREDSTOCK': balance_sheets['preferredStock'].astype('int64'),
    'COMMONSTOCK': balance_sheets['commonStock'].astype('int64'),
    'RETAINEDEARNINGS': balance_sheets['retainedEarnings'].astype('int64'),
    'ACCUMULATEDOTHERCOMPREHENSIVEINCOMELOSS': balance_sheets['accumulatedOtherComprehensiveIncomeLoss'].astype('int64'),
    'OTHERTOTALSTOCKHOLDERSEQUITY': balance_sheets['othertotalStockholdersEquity'].astype('int64'),
    'TOTALSTOCKHOLDERSEQUITY': balance_sheets['totalStockholdersEquity'].astype('int64'),
    'TOTALEQUITY': balance_sheets['totalEquity'].astype('int64'),
    'TOTALLIABILITIESANDSTOCKHOLDERSEQUITY': balance_sheets['totalLiabilitiesAndStockholdersEquity'].astype('int64'),
    'MINORITYINTEREST': balance_sheets['minorityInterest'].astype('int64'),
    'TOTALLIABILITIESANDTOTALEQUITY': balance_sheets['totalLiabilitiesAndTotalEquity'].astype('int64'),
    'TOTALINVESTMENTS': balance_sheets['totalInvestments'].astype('int64'),
    'TOTALDEBT': balance_sheets['totalDebt'].fillna(0).astype('int64'),
    'NETDEBT': balance_sheets['netDebt'].fillna(0).astype('int64'),
    'LINK': balance_sheets['link'].astype(str),
    'FINALLINK': balance_sheets['finalLink'].astype(str),
    'TICKER': balance_sheets['Ticker'].astype(str),
})

project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'balance_sheets'

# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = f'{project_id}.{dataset_id}.{table_name}'

# Write the DataFrame to BigQuery with schema auto-detection
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",
)

client.load_table_from_dataframe(
    balance_sheets, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=7da119ec-7322-482f-b19d-75c4c775b99d>

# %%
job_id = '7da119ec-7322-482f-b19d-75c4c775b99d'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Cash Flow Statements

# %%
# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/cash-flow-statement-shorten/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.content.decode('utf-8-sig')

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker
    
    # Remove the 'label' column
    # df.drop('netCashProvidedByOperatingActivites', axis=1, inplace=True)

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df


# concatenate all dataframes into one
cash_flows_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
cash_flows_df.to_csv("cash_flows.csv", index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
cash_flow_statements = pd.read_csv('cash_flows.csv')

# Check if the column exists before dropping it
column_to_drop = 'netCashProvidedByOperatingActivites'
if column_to_drop in cash_flow_statements.columns:
    cash_flow_statements.drop(columns=[column_to_drop], inplace=True)

# Convert specified columns to datetime format
# date_columns = ['date', 'fillingDate', 'acceptedDate']
# cash_flows_df[date_columns] = cash_flows_df[date_columns].apply(pd.to_datetime)


# Explicitly set the 'DATE' column as datetime64[ns]
cash_flow_statements = pd.DataFrame({
    'DATE': pd.to_datetime(cash_flow_statements['date'], errors='coerce'),
    'SYMBOL': cash_flow_statements['symbol'].astype(str),
    'REPORTEDCURRENCY': cash_flow_statements['reportedCurrency'].astype(str),
    'CIK': cash_flow_statements['cik'].astype(int),
    'FILLINGDATE': pd.to_datetime(cash_flow_statements['fillingDate'], errors='coerce'),
    'ACCEPTEDDATE': pd.to_datetime(cash_flow_statements['acceptedDate'], errors='coerce'),
    'CALENDARYEAR': cash_flow_statements['calendarYear'].astype(int),
    'PERIOD': cash_flow_statements['period'].astype(str),
    'NETINCOME': cash_flow_statements['netIncome'].astype(int),
    'DEPRECIATIONANDAMORTIZATION': cash_flow_statements['depreciationAndAmortization'].astype(int),
    'DEFERREDINCOMETAX': cash_flow_statements['deferredIncomeTax'].astype(int),
    'STOCKBASEDCOMPENSATION': cash_flow_statements['stockBasedCompensation'].astype(int),
    'CHANGEINWORKINGCAPITAL': cash_flow_statements['changeInWorkingCapital'].astype(int),
    'ACCOUNTSRECEIVABLES': cash_flow_statements['accountsReceivables'].astype(int),
    'INVENTORY': cash_flow_statements['inventory'].astype(int),
    'ACCOUNTSPAYABLES': cash_flow_statements['accountsPayables'].astype(int),
    'OTHERWORKINGCAPITAL': cash_flow_statements['otherWorkingCapital'].astype(int),
    'OTHERNONCASHITEMS': cash_flow_statements['otherNonCashItems'].astype(int),
    'NETCASHPROVIDEDBYOPERATINGACTIVITIES': cash_flow_statements['netCashProvidedByOperatingActivities'].astype(int),
    'INVESTMENTSINPROPERTYPLANTANDEQUIPMENT': cash_flow_statements['investmentsInPropertyPlantAndEquipment'].astype(int),
    'ACQUISITIONSNET': cash_flow_statements['acquisitionsNet'].astype(int),
    'PURCHASESOFINVESTMENTS': cash_flow_statements['purchasesOfInvestments'].astype(int),
    'SALESMATURITIESOFINVESTMENTS': cash_flow_statements['salesMaturitiesOfInvestments'].astype(int),
    'OTHERINVESTINGACTIVITES': cash_flow_statements['otherInvestingActivites'].astype(int),
    'NETCASHUSEDFORINVESTINGACTIVITES': cash_flow_statements['netCashUsedForInvestingActivites'].astype(int),
    'DEBTREPAYMENT': cash_flow_statements['debtRepayment'].astype(int),
    'COMMONSTOCKISSUED': cash_flow_statements['commonStockIssued'].astype(int),
    'COMMONSTOCKREPURCHASED': cash_flow_statements['commonStockRepurchased'].astype(int),
    'DIVIDENDSPAID': cash_flow_statements['dividendsPaid'].astype(int),
    'OTHERFINANCINGACTIVITES': cash_flow_statements['otherFinancingActivites'].astype(int),
    'NETCASHUSEDPROVIDEDBYFINANCINGACTIVITIES': cash_flow_statements['netCashUsedProvidedByFinancingActivities'].astype(int),
    'EFFECTOFFOREXCHANGESONCASH': cash_flow_statements['effectOfForexChangesOnCash'].astype(int),
    'NETCHANGEINCASH': cash_flow_statements['netChangeInCash'].astype(int),
    'CASHATENDOFPERIOD': cash_flow_statements['cashAtEndOfPeriod'].astype(int),
    'CASHATBEGINNINGOFPERIOD': cash_flow_statements['cashAtBeginningOfPeriod'].astype(int),
    'OPERATINGCASHFLOW': cash_flow_statements['operatingCashFlow'].astype(int),
    'CAPITALEXPENDITURE': cash_flow_statements['capitalExpenditure'].astype(int),
    'FREECASHFLOW': cash_flow_statements['freeCashFlow'].astype(int),
    'LINK': cash_flow_statements['link'].astype(str),
    'FINALLINK': cash_flow_statements['finalLink'].astype(str),
    'TICKER': cash_flow_statements['Ticker'].astype(str),
})

cash_flow_statements.columns = cash_flow_statements.columns.str.upper()


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'cash_flow_statements'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.cash_flow_statements'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


client.load_table_from_dataframe(
    cash_flow_statements, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=02a1bde7-dbcc-465a-8c15-f1a7b68e8941>

# %%
job_id = '02a1bde7-dbcc-465a-8c15-f1a7b68e8941'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Daily Market Caps

# %%
import requests
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/historical-market-capitalization/{}?limit=10000&datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker) 

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.content.decode('utf-8-sig')

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # Rename the 'symbol' column to 'ticker'
    df.rename(columns={'symbol': 'ticker'}, inplace=True)

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
market_cap_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
market_cap_df.to_csv("market_cap.csv", index=False)

# %% [markdown]
# Get Daily Prices

# %%
from pandas.errors import EmptyDataError

import requests 
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker 
url_template = "https://fmpcloud.io/api/v3/historical-price-full/{}?datatype=csv&serietype=line&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes 
ticker_dataframes = {}

# define a list of tickers 
tickers = tickers

try: 
    # loop over the tickers and make an API request for each one 
    for ticker in tickers:
        # replace the placeholder with the current ticker 
        url = url_template.format(ticker)  
    
        # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
        try:
            response = requests.get(url)
            data = response.content.decode('utf-8-sig')  
        except EmptyDataError as e:
            print(f'No data for {ticker} ticker. Skipping...')
            continue  
            
        # create a dataframe from the data 
        df = pd.read_csv(io.StringIO(data))  
        
        # Add 'ticker' column with the current ticker value 
        df['ticker'] = ticker  
        
        # Remove the 'label' column 
        df.drop('label', axis=1, inplace=True)  
        
        # store the dataframe in the ticker_dataframes dictionary with the ticker as the key 
        ticker_dataframes[ticker] = df      

except Exception as e:
    print(f"An error occurred: {e}")
   
# concatenate all dataframes into one  
daily_prices_df = pd.concat(ticker_dataframes.values(), ignore_index=True)    

# save the combined dataframe as a CSV file 
daily_prices_df.to_csv("daily_prices.csv", index=False)
# Out:
# An error occurred: No columns to parse from file

# %%
import pandas as pd

# Load the daily prices dataframe
daily_prices_df = pd.read_csv("daily_prices.csv")

# Load the market cap dataframe
market_cap_df = pd.read_csv("market_cap.csv")

# Merge the dataframes based on 'ticker' and 'date' columns
market_cap_close_price = pd.merge(daily_prices_df, market_cap_df, on=['ticker', 'date'])

# Reorder the columns
market_cap_close_price = market_cap_close_price[['ticker', 'date', 'close', 'marketCap']]

# Save the merged dataframe as a CSV file
market_cap_close_price.to_csv("market_cap_price_history.csv", index=False)



# Load the merged dataframe
market_cap_close_price = pd.read_csv("market_cap_price_history.csv")

# Convert 'date' column to datetime
market_cap_close_price['date'] = pd.to_datetime(market_cap_close_price['date'])

# Convert 'close' column to float with 2 decimal places
market_cap_close_price['close'] = market_cap_close_price['close'].astype(float).round(2)

# Convert 'marketCap' column to integer
market_cap_close_price['marketCap'] = market_cap_close_price['marketCap'].astype(int)

#convert lowercase to uppercase
market_cap_close_price.columns = market_cap_close_price.columns.str.upper()

market_cap_close_price['DATE'] = pd.to_datetime(market_cap_close_price['DATE'], errors='coerce')

market_cap_close_price['MARKETCAP'] = market_cap_close_price['MARKETCAP'].astype(int)

# Save the modified dataframe as a CSV file
market_cap_close_price.to_csv("market_cap_price_history.csv", index=False)

# %% [markdown]
# #### Writeback to BigQuery

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Explicitly set the 'DATE' column as datetime64[ns]
market_cap_price_history = pd.DataFrame({
    'TICKER': market_cap_close_price['TICKER'],
    'DATE': pd.to_datetime(market_cap_close_price['DATE'], errors='coerce'),
    'CLOSE': market_cap_close_price['CLOSE'],
    'MARKETCAP': market_cap_close_price['MARKETCAP'].astype(int)
})

project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'market_cap_price_history'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.market_cap_price_history'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)

# Assuming market_cap_price_history is your DataFrame
client.load_table_from_dataframe(
    market_cap_price_history, destination_table, job_config=job_config
).result()
# Out:
# LoadJob<project=stock-market-data-391622, location=US, id=c6d7e8c6-2cc4-4362-84f3-c57e63facb2d>

# %%
job_id = 'c6d7e8c6-2cc4-4362-84f3-c57e63facb2d'  # Replace with your actual job ID
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Enterprise Values

# %%
import requests
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/enterprise-values/{}?datatype=csv&period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.content.decode('utf-8-sig')

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
enterprise_values_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

#convert columns for database
enterprise_values_df.columns = enterprise_values_df.columns.str.upper()

enterprise_values_df['DATE'] = pd.to_datetime(enterprise_values_df['DATE'], errors='coerce')

# save the combined dataframe as a CSV file
enterprise_values_df.to_csv("enterprise_values.csv", index=False)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

enterprise_values_df = enterprise_values_df.replace([np.inf, -np.inf], np.nan)
enterprise_values_df = enterprise_values_df.fillna(0)  # Replace NaN with 0 or use another suitable value

enterprise_values = pd.DataFrame({
    'SYMBOL': enterprise_values_df['SYMBOL'],
    'DATE': pd.to_datetime(enterprise_values_df['DATE'], errors='coerce'),
    'STOCKPRICE': enterprise_values_df['STOCKPRICE'].astype(float),
    'NUMBEROFSHARES': enterprise_values_df['NUMBEROFSHARES'].astype(int),
    'MARKETCAPITALIZATION': enterprise_values_df['MARKETCAPITALIZATION'].astype(int),
    'MINUSCASHANDCASHEQUIVALENTS': enterprise_values_df['MINUSCASHANDCASHEQUIVALENTS'].astype(int),
    'ADDTOTALDEBT': enterprise_values_df['ADDTOTALDEBT'].astype(int),
    'ENTERPRISEVALUE': enterprise_values_df['ENTERPRISEVALUE'].astype(int),
    'TICKER': enterprise_values_df['TICKER']
})


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'enterprise_values'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.enterprise_values'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)

# Assuming market_cap_price_history is your DataFrame
load_job = client.load_table_from_dataframe(
    enterprise_values, destination_table, job_config=job_config
)

load_job.result()

ev_job_id = load_job.job_id
print(f"Job ID: {job_id}")
# Out:
# Job ID: c6d7e8c6-2cc4-4362-84f3-c57e63facb2d

# %%
job_id = ev_job_id
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Get Headcount

# %%
import requests
import pandas as pd
import io

tickers = tickers

all_data = []
for ticker in tickers:
    url = f"https://fmpcloud.io/api/v3/profile/{ticker}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"
    r = requests.get(url)
    data = r.text 
    df = pd.read_csv(io.StringIO(data))
    
    try: 
        df = df[["symbol", "companyName", "fullTimeEmployees", "mktCap", "sector", "industry", "country", "ipoDate", "cik", "isin", "cusip"]]
        all_data.append(df)
    except KeyError:
        continue  # Skip to next ticker

semi_segment_headcount = pd.concat(all_data) 
semi_segment_headcount.to_csv("headcount.csv")

# %% [markdown]
# Get financial statements growth

# %%
import pandas as pd
import csv
import os
import requests
import glob
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/financial-growth/{}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("financial_statement_growth_FY.csv", index=False)

# %%
import pandas as pd

# concatenate all dataframes into one
financial_statement_growth = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
financial_statement_growth.to_csv("financial_statement_growth_FY.csv", index=False)

# %%
import pandas as pd
import csv
import os
import requests
import glob
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/financial-growth/{}?period=quarter&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    
    # check if the request was successful (status code 200)
    if response.status_code == 200:
        try:
            # retrieve the data in JSON format
            data = response.json()

            # create a dataframe from the data
            df = pd.json_normalize(data)  # Use json_normalize to flatten the nested JSON structure

            # add a new column to the dataframe with the ticker symbol
            df['Ticker'] = ticker

            # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
            ticker_dataframes[ticker] = df
        except ValueError as e:
            pass  # Optionally, you can log or handle the error here without printing
    else:
        pass  # Optionally, you can log or handle the error here without printing

# concatenate all dataframes into one
combined_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
combined_df.to_csv("financial_statement_growth_quarterly.csv", index=False)

# %%
# save the combined dataframe as a CSV file
combined_df.to_csv("financial_statement_growth_quarterly.csv", index=False)

# %%
import csv

original_order = ['symbol', 'date', 'calendarYear', 'period', 'revenueGrowth', 'grossProfitGrowth', 'ebitgrowth', 
'operatingIncomeGrowth', 'netIncomeGrowth', 'epsgrowth', 'epsdilutedGrowth', 'weightedAverageSharesGrowth', 
'weightedAverageSharesDilutedGrowth', 'dividendsperShareGrowth', 'operatingCashFlowGrowth', 'freeCashFlowGrowth', 
'tenYRevenueGrowthPerShare', 'fiveYRevenueGrowthPerShare', 'threeYRevenueGrowthPerShare', 'tenYOperatingCFGrowthPerShare', 
'fiveYOperatingCFGrowthPerShare', 'threeYOperatingCFGrowthPerShare', 'tenYNetIncomeGrowthPerShare', 
'fiveYNetIncomeGrowthPerShare', 'threeYNetIncomeGrowthPerShare', 'tenYShareholdersEquityGrowthPerShare', 
'fiveYShareholdersEquityGrowthPerShare', 'threeYShareholdersEquityGrowthPerShare', 'tenYDividendperShareGrowthPerShare', 
'fiveYDividendperShareGrowthPerShare', 'threeYDividendperShareGrowthPerShare', 'receivablesGrowth', 'inventoryGrowth', 
'assetGrowth', 'bookValueperShareGrowth', 'debtGrowth', 'rdexpenseGrowth', 'sgaexpensesGrowth', 'Ticker']

desired_order = ['Ticker', 'date', 'period', 'revenueGrowth', 'grossProfitGrowth', 'ebitgrowth', 
'operatingIncomeGrowth', 'netIncomeGrowth', 'epsgrowth', 'epsdilutedGrowth', 'weightedAverageSharesGrowth', 
'weightedAverageSharesDilutedGrowth', 'dividendsperShareGrowth', 'operatingCashFlowGrowth', 'freeCashFlowGrowth', 
'tenYRevenueGrowthPerShare', 'fiveYRevenueGrowthPerShare', 'threeYRevenueGrowthPerShare', 'tenYOperatingCFGrowthPerShare', 
'fiveYOperatingCFGrowthPerShare', 'threeYOperatingCFGrowthPerShare', 'tenYNetIncomeGrowthPerShare', 
'fiveYNetIncomeGrowthPerShare', 'threeYNetIncomeGrowthPerShare', 'tenYShareholdersEquityGrowthPerShare', 
'fiveYShareholdersEquityGrowthPerShare', 'threeYShareholdersEquityGrowthPerShare', 'tenYDividendperShareGrowthPerShare', 
'fiveYDividendperShareGrowthPerShare', 'threeYDividendperShareGrowthPerShare', 'receivablesGrowth', 'inventoryGrowth', 
'assetGrowth', 'bookValueperShareGrowth', 'debtGrowth', 'rdexpenseGrowth', 'sgaexpensesGrowth']

with open('financial_statement_growth_quarterly.csv', 'r') as f:
  reader = csv.reader(f)
  rows = list(reader)
  
header = rows[0] 
data = rows[1:]

reordered_header = [header[original_order.index(col)] for col in desired_order]  

reordered_data = []
for row in data:
  reordered_data.append([row[original_order.index(col)] for col in desired_order])
  
with open('financial_statement_growth_quarterly.csv', 'w') as f:
  writer = csv.writer(f)
  writer.writerow(reordered_header)
  writer.writerows(reordered_data)

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd

# Read the CSV file into a DataFrame
financial_growth = pd.read_csv('financial_statement_growth_quarterly.csv')

# Handle Non-finite Values:
# financial_growth['averageInventory'] = financial_growth['averageInventory'].fillna(0).astype(int)

# Convert 'date' column to datetime format
# financial_growth['DATE'] = pd.to_datetime(financial_growth['date'], errors='coerce')

# Create the new DataFrame with all specified columns and data types
financial_growth = pd.DataFrame({
    'SYMBOL': financial_growth['Ticker'],
    'DATE': pd.to_datetime(financial_growth['date'], errors='coerce'),
    'PERIOD': financial_growth['period'],
    'REVENUE_GROWTH': financial_growth['revenueGrowth'].astype(float),
    'GROSS_PROFIT_GROWTH': financial_growth['grossProfitGrowth'].astype(float),
    'EBIT_GROWTH': financial_growth['ebitgrowth'].astype(float),
    'OPERATING_INCOME_GROWTH': financial_growth['operatingIncomeGrowth'].astype(float),
    'NET_INCOME_GROWTH': financial_growth['netIncomeGrowth'].astype(float),
    'EPS_GROWTH': financial_growth['epsgrowth'].astype(float),
    'EPS_DILUTED_GROWTH': financial_growth['epsdilutedGrowth'].astype(float),
    'WEIGHTED_AVERAGE_SHARES_GROWTH': financial_growth['weightedAverageSharesGrowth'].astype(float),
    'WEIGHTED_AVERAGE_SHARES_DILUTED_GROWTH': financial_growth['weightedAverageSharesDilutedGrowth'].astype(float),
    'DIVIDENDS_PER_SHARE_GROWTH': financial_growth['dividendsperShareGrowth'].astype(float),
    'OPERATING_CASH_FLOW_GROWTH': financial_growth['operatingCashFlowGrowth'].astype(float),
    'FREE_CASH_FLOW_GROWTH': financial_growth['freeCashFlowGrowth'].astype(float),
    'TEN_Y_REVENUE_GROWTH_PER_SHARE': financial_growth['tenYRevenueGrowthPerShare'].astype(float),
    'FIVE_Y_REVENUE_GROWTH_PER_SHARE': financial_growth['fiveYRevenueGrowthPerShare'].astype(float),
    'THREE_Y_REVENUE_GROWTH_PER_SHARE': financial_growth['threeYRevenueGrowthPerShare'].astype(float),
    'TEN_Y_OPERATING_CF_GROWTH_PER_SHARE': financial_growth['tenYOperatingCFGrowthPerShare'].astype(float),
    'FIVE_Y_OPERATING_CF_GROWTH_PER_SHARE': financial_growth['fiveYOperatingCFGrowthPerShare'].astype(float),
    'THREE_Y_OPERATING_CF_GROWTH_PER_SHARE': financial_growth['threeYOperatingCFGrowthPerShare'].astype(float),
    'TEN_Y_NET_INCOME_GROWTH_PER_SHARE': financial_growth['tenYNetIncomeGrowthPerShare'].astype(float),
    'FIVE_Y_NET_INCOME_GROWTH_PER_SHARE': financial_growth['fiveYNetIncomeGrowthPerShare'].astype(float),
    'THREE_Y_NET_INCOME_GROWTH_PER_SHARE': financial_growth['threeYNetIncomeGrowthPerShare'].astype(float),
    'TEN_Y_SHAREHOLDERS_EQUITY_GROWTH_PER_SHARE': financial_growth['tenYShareholdersEquityGrowthPerShare'].astype(float),
    'FIVE_Y_SHAREHOLDERS_EQUITY_GROWTH_PER_SHARE': financial_growth['fiveYShareholdersEquityGrowthPerShare'].astype(float),
    'THREE_Y_SHAREHOLDERS_EQUITY_GROWTH_PER_SHARE': financial_growth['threeYShareholdersEquityGrowthPerShare'].astype(float),
    'TEN_Y_DIVIDEND_PER_SHARE_GROWTH_PER_SHARE': financial_growth['tenYDividendperShareGrowthPerShare'].astype(float),
    'FIVE_Y_DIVIDEND_PER_SHARE_GROWTH_PER_SHARE': financial_growth['fiveYDividendperShareGrowthPerShare'].astype(float),
    'THREE_Y_DIVIDEND_PER_SHARE_GROWTH_PER_SHARE': financial_growth['threeYDividendperShareGrowthPerShare'].astype(float),
    'RECEIVABLES_GROWTH': financial_growth['receivablesGrowth'].astype(float),
    'INVENTORY_GROWTH': financial_growth['inventoryGrowth'].astype(float),
    'ASSET_GROWTH': financial_growth['assetGrowth'].astype(float),
    'BOOK_VALUE_PER_SHARE_GROWTH': financial_growth['bookValueperShareGrowth'].astype(float),
    'DEBT_GROWTH': financial_growth['debtGrowth'].astype(float),
    'RD_EXPENSE_GROWTH': financial_growth['rdexpenseGrowth'].astype(float),
    'SGA_EXPENSES_GROWTH': financial_growth['sgaexpensesGrowth'].astype(float),
})

financial_growth.columns = financial_growth.columns.str.upper()


# Convert DATE column to datetime
financial_growth['DATE'] = pd.to_datetime(financial_growth['DATE'], errors='coerce')


project_id = 'stock-market-data-391622'
dataset_id = 'market_information'
table_name = 'financial_growth'


# Create a BigQuery client with service account credentials
credentials = service_account.Credentials.from_service_account_file('stock-market-data-391622-03ee9e592be9.json')
client = bigquery.Client(credentials=credentials, project=project_id)

# Specify the destination table in BigQuery
destination_table = 'stock-market-data-391622.market_information.financial_growth'


# Write the DataFrame to BigQuery without specifying the schema
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # Options: "WRITE_TRUNCATE", "WRITE_APPEND", "WRITE_EMPTY", "WRITE_TRUNCATE"
)


load_job = client.load_table_from_dataframe(
    financial_growth, destination_table, job_config=job_config
)

load_job.result()

fgq_job_id = load_job.job_id
print(f"Job ID: {job_id}")
# Out:
# Job ID: 194a3deb-1da2-4534-a09c-e720023856ef

# %%
job_id = fgq_job_id
job = client.get_job(job_id)
print(job.state)
# Out:
# DONE

# %% [markdown]
# Financial Growth Recent Quarter Rank - via Mode Query: [https://app.mode.com/editor/pirates_united/datasets/57c6e18c5304/queries/6cbe513a8781](https://app.mode.com/editor/pirates_united/datasets/57c6e18c5304/queries/6cbe513a8781)
#
#
#
# Most Recent 8 Quarters: [https://app.mode.com/editor/pirates_united/datasets/56f147dbbe1b/queries/1671ad60185a](https://app.mode.com/editor/pirates_united/datasets/56f147dbbe1b/queries/1671ad60185a)
#
#
#
# Most Recent Year: [https://app.mode.com/editor/pirates_united/datasets/eddf7f4c3629/queries/35ff1fda440b](https://app.mode.com/editor/pirates_united/datasets/eddf7f4c3629/queries/35ff1fda440b)

# %%
import pandas as pd

# Read data from the CSV file into a DataFrame
data_file = 'most_recent_quarter_-_financial_growth_snapshot-dataset-6cbe513a8781-2023-12-10-21-17-15.csv'
df = pd.read_csv(data_file)

# Filter rows where PERIOD is Q3
q3_data = df[df['PERIOD'] == 'Q3']

# Rank each value in each column independently
ranked_data = q3_data.apply(lambda x: x.rank(ascending=False, method='max'), axis=0)

# Combine the SYMBOL, DATE, PERIOD columns with the ranked data
result_df = pd.concat([q3_data[['SYMBOL', 'DATE', 'PERIOD']], ranked_data], axis=1)

# Save the result
result_df.to_csv("ranked_data_q3.csv", index=False)

# %%
import pandas as pd

# Read data from the CSV file into a DataFrame
data_file = 'ranked_data_q3.csv'
df = pd.read_csv(data_file)

# Filter rows where PERIOD is Q3
q3_data = df[df['PERIOD'] == 'Q3']

# Calculate percentiles for each numeric column
percentiles_data = q3_data.iloc[:, 3:].apply(lambda x: x.rank(pct=True), axis=0)

# Combine the SYMBOL, DATE, PERIOD columns with the percentiles data
result_df = pd.concat([q3_data[['SYMBOL', 'DATE', 'PERIOD']], percentiles_data], axis=1)

# Save the result
result_df.to_csv("percentiles_data_q3.csv", index=False)

# %%
import requests
import pandas as pd
import io

# set the API endpoint URL with a placeholder for the ticker
url_template = "https://fmpcloud.io/api/v3/historical-discounted-cash-flow-statement/{}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86"

# define a dictionary to store ticker dataframes
ticker_dataframes = {}

# define a list of tickers
tickers = tickers

# loop over the tickers and make an API request for each one
for ticker in tickers:
    # replace the placeholder with the current ticker
    url = url_template.format(ticker)

    # make an HTTP GET request to the API endpoint and retrieve the data in CSV format
    response = requests.get(url)
    data = response.text

    # create a dataframe from the data
    df = pd.read_csv(io.StringIO(data))

    # add a new column to the dataframe with the ticker symbol
    df['Ticker'] = ticker

    # store the dataframe in the ticker_dataframes dictionary with the ticker as the key
    ticker_dataframes[ticker] = df

# concatenate all dataframes into one
dcf_df = pd.concat(ticker_dataframes.values(), ignore_index=True)

# save the combined dataframe as a CSV file
dcf_df.to_csv("dcf.csv", index=False)

# %%
# import jinja2
# raw_query = """
#     SELECT *, ROUND((dcf / price - 1), 2) as dcf_to_price_delta_rate
#     FROM dcf_df
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT MAX(date) as most_recent_date, Ticker, dcf_to_price_delta_rate
#     FROM dcf_delta
#     WHERE date >= '2022-01-01'
#     GROUP BY Ticker, dcf_to_price_delta_rate
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import certifi
import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v4/revenue-product-segmentation?symbol=AAPL&structure=flat&apikey=a726d5acabd86910ef2749315f5eaa86")
print(get_jsonparsed_data(url))
# Out:
# Could not find product segmentation for Revenue from Contract with Customer

# %% [markdown]
# Get Sector and Industry P/Es

# %%
import pandas as pd
import urllib.request
import io
import json
import datetime

# Define list of exchanges
exchanges = ['NYSE', 'NASDAQ', 'TSX', 'PNK', 'OTC', 'LSE', 'EURONEXT', 'CNQ', 'ASX', 'AMS']

dfs = []

# Get the most recent weekday
today = datetime.date.today()
if today.weekday() == 5:  # Saturday
    today -= datetime.timedelta(days=1)
elif today.weekday() == 6:  # Sunday
    today -= datetime.timedelta(days=2)

# Add the current date to the list of dates
dates = [today]

# Add the last 20 years, at 1 year intervals, to the list of dates
for i in range(1, 21):
    year = today.year - i
    date = datetime.date(year, today.month, today.day)
    dates.append(date)

# Loop through dates and exchanges and pull data for each one
for date in dates:
    for exchange in exchanges:
        # Build API URL with dynamic date and exchange
        url = f'https://fmpcloud.io/api/v4/sector_price_earning_ratio?date={date}&exchange={exchange}&apikey=a726d5acabd86910ef2749315f5eaa86'
        
        # Make API request and read response
        response = urllib.request.urlopen(url)
        data = response.read().decode('utf-8')
        
        # Convert JSON response to DataFrame
        json_data = json.loads(data)
        df = pd.json_normalize(json_data)
        
        # Add date column to DataFrame
        df['date'] = date.strftime('%Y-%m-%d')
        
        # Append DataFrame to list
        dfs.append(df)
    
# Concatenate all DataFrames in the list
sector_price_earning_ratio = pd.concat(dfs, ignore_index=True)

# Save result as CSV file
sector_price_earning_ratio.to_csv('sector_price_earning_ratio.csv', index=False)

# %%
# import jinja2
# raw_query = """
#     SELECT date,
#     sector, 
#     exchange,
#     ROUND(CAST(pe AS DECIMAL), 2) as pe_ratio
#     from sector_price_earning_ratio
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import pandas as pd
import urllib.request
import io
import json
import datetime

# Define list of exchanges
exchanges = ['NYSE', 'NASDAQ', 'TSX', 'PNK', 'OTC', 'LSE', 'EURONEXT', 'CNQ', 'ASX', 'AMS']

dfs = []

# Get the most recent weekday
today = datetime.date.today()
if today.weekday() == 5:  # Saturday
    today -= datetime.timedelta(days=1)
elif today.weekday() == 6:  # Sunday
    today -= datetime.timedelta(days=2)

# Add the current date to the list of dates
dates = [today]

# Add the last 20 years, at 1 year intervals, to the list of dates
for i in range(1, 21):
    year = today.year - i
    date = datetime.date(year, today.month, today.day)
    dates.append(date)

# Loop through dates and exchanges and pull data for each one
for date in dates:
    for exchange in exchanges:
        # Build API URL with dynamic date and exchange
        url = f'https://fmpcloud.io/api/v4/industry_price_earning_ratio?date={date}&exchange={exchange}&apikey=a726d5acabd86910ef2749315f5eaa86'
        
        # Make API request and read response
        response = urllib.request.urlopen(url)
        data = response.read().decode('utf-8')
        
        # Convert JSON response to DataFrame
        json_data = json.loads(data)
        df = pd.json_normalize(json_data)
        
        # Add date column to DataFrame
        df['date'] = date.strftime('%Y-%m-%d')
        
        # Append DataFrame to list
        dfs.append(df)
    
# Concatenate all DataFrames in the list
industry_price_earning_ratio = pd.concat(dfs, ignore_index=True)

# Save result as CSV file
industry_price_earning_ratio.to_csv('industry_price_earning_ratio.csv', index=False)

# %%
# import jinja2
# raw_query = """
#     SELECT date,
#     industry, 
#     exchange,
#     ROUND(CAST(pe AS DECIMAL), 2) as pe_ratio
#     from industry_price_earning_ratio
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %% [markdown]
# Company Overview

# %%
import pandas as pd

# Define the list of tickers
tickers = sp500_symbol_list

# Initialize an empty dictionary to store the dataframes for each ticker
dfs = {}

# Loop through each ticker and pull the data
for ticker in tickers:
    url = f'https://fmpcloud.io/api/v3/profile/{ticker}?datatype=csv&apikey=a726d5acabd86910ef2749315f5eaa86'
    df = pd.read_csv(url)
    dfs[ticker] = df

# Concatenate all the dataframes into a single dataframe
df_all = pd.concat(dfs.values(), axis=0)

# Save the final dataframe as a CSV file
df_all.to_csv('sp500_company_overview_ALL.csv', index=False)

# Display a message to confirm that the file has been saved
print('CSV file saved')

# %% [markdown]
# ### __**Get Supply Chain Relationships**__

# %%
import csv
import requests

url = "https://versed-ai.api.blobr.app/gf3h496c31r353px/companies/"
headers = {
  "X-BLOBR-KEY": "PQgP7gAI9kIKcMdZAiPnKsz80dUTlB1i"
}

params = {
    "country": "USA",
    "include_subsidiaries": "TRUE",
    "limit": 100,
    "offset": 0,
    "ordering": "-count_supplier_evidence,-count_customer_evidence,-count_suppliers,-count_customers"
}

response = requests.get(url, headers=headers, params=params)

data = response.json()["results"]

# Open a new CSV file for writing
with open("supply_chain_relationships_info.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # Write the header row
    writer.writerow([
        "Name",
        "vid",
        "description",
        "ipo_date",
        "is_public",
        "domiciled_country",
        "Count Suppliers",
        "Count Customers",
        "Count Supplier Evidence",
        "Count Customer Evidence"
    ])

    # Write each company's data as a row in the CSV file
    for company in data:
        writer.writerow([
            company["name"],
            company.get("vid"),
            company.get("description"),
            company.get("ipo_date"),
            company.get("is_public"),
            company.get("domiciled_country"),
            company["count_suppliers"],
            company["count_customers"],
            company["count_supplier_evidence"],
            company["count_customer_evidence"]
        ])

# %%
# import jinja2
# raw_query = """
#     SELECT vid from 'supply_chain_relationships_info.csv'
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import requests
import csv
import pandas as pd

# Read the company vid's from the CSV file
df = pd.read_csv("supply_chain_relationships_info.csv")

# Define the output CSV file and write the header row
output_file = open("supply_chain_relationships_supplier_pairs.csv", "w", newline="")
writer = csv.writer(output_file)
writer.writerow(["Company Name", "Supplier Name", "Supplier Country", "Supplier ID"])

# Loop over each company vid in the DataFrame
for vid in df['vid']:
    # Construct the API endpoint URL
    url = f"https://versed-ai.api.blobr.app/gf3h496c31r353px/companies/{vid}/suppliers/"

    # Send the HTTP GET request to the API endpoint
    response = requests.get(url)

    # Parse the JSON response into a Python dictionary
    response_json = response.json()

    # Loop over each supplier in the response and write the data to the CSV file
    for supplier in response_json:
        writer.writerow([supplier["company"]["name"], supplier["name"], supplier.get("country", ""), supplier["id"]])

# Close the output CSV file
output_file.close()

# %%
import csv
import requests

url = "https://versed-ai.api.blobr.app/gf3h496c31r353px/companies/{vid}/suppliers/"
headers = {
  "X-BLOBR-KEY": "PQgP7gAI9kIKcMdZAiPnKsz80dUTlB1i"
}

vid = 'amazoncominc-db72624a-c1a5-4936-9459-eaf3fe7c7565'

params = {
    "vid": "amazoncominc-db72624a-c1a5-4936-9459-eaf3fe7c7565",
    "limit": 10,
    "offset": 0
}

response = requests.get(url, headers=headers, params=params)

data = response.json()["results"]

# Open a new CSV file for writing
with open("supply_chain_relationships_suppliers.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # Write the header row
    writer.writerow([
        "vid",
        "confidence_score",
        "description",
        "ipo_date",
        "is_public",
        "domiciled_country",
        "Count Suppliers",
        "Count Customers",
        "Count Supplier Evidence",
        "Count Customer Evidence"
    ])

    # Write each company's data as a row in the CSV file
    for company in data:
        writer.writerow([
            company["name"],
            company.get("vid"),
            company.get("description"),
            company.get("ipo_date"),
            company.get("is_public"),
            company.get("domiciled_country"),
            company["count_suppliers"],
            company["count_customers"],
            company["count_supplier_evidence"],
            company["count_customer_evidence"]
        ])

# %% [markdown]
# Push to Snowflake

# %%
pip install dateparser
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 38.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('semi_industry_supply_chain_relationships.csv')

supplier_name = df['supplier_name']

# %%
with open('semi_industry_supply_chain_relationships.csv', 'r', encoding='utf-8-sig') as input_file:
    csv_reader = csv.DictReader(input_file, delimiter=',')
    with open('semi_industry_supply_chain_relationships_updated.csv', 'w', newline='', encoding='utf-8') as output_file:
        fieldnames = csv_reader.fieldnames
        csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)
        csv_writer.writeheader()
        for i, row in enumerate(csv_reader):
            csv_writer.writerow(row)

# %%
import csv

with open('semi_industry_supply_chain_relationships_updated.csv', 'rt', encoding='utf-8-sig') as csvfile:
    csv_reader = csv.DictReader(csvfile, delimiter=',')
    print(csv_reader.fieldnames)

# %%
import pandas as pd

# read in the input file
input_file = "semi_industry_supply_chain_relationships_updated.csv"
df = pd.read_csv(input_file)

# save the dataframe as a CSV file
output_file = "semi_industry_supply_chain_relationships_updated.csv"
df.to_csv(output_file, index=False)

# %%
import snowflake.connector
import csv
import datetime
import dateparser

sf_connection = {
    "account": "traqatz-jxb84528",
    "user": "nickwarner29",
    "password": "Minne55331!",
    "database": "PC_HEX_DB",
    "schema": "PUBLIC",
    "warehouse": "COMPUTE_WH",
}

conn = snowflake.connector.connect(**sf_connection)
cs = conn.cursor()

# Load the CSV file into a list of dictionaries
rows = []
with open('semi_industry_supply_chain_relationships_updated.csv', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile, delimiter=',')
    for row in csv_reader:
        new_row = {
            "created_date": row["created_date"],
            "supplier_name": row["supplier_name"],
            "supplier_ticker": row["supplier_ticker"],
            "supplier_sector": row["supplier_sector"],
            "supplier_industry": row["supplier_industry"],
            "supplier_country": row["supplier_country"],
            "supplier_employees": row["supplier_employees"],
            "supplier_mkt_cap_category": row["supplier_mkt_cap_category"],
            "customer_name": row["customer_name"],
            "customer_ticker": row["customer_ticker"],
            "rate_of_semi_industry_revenue": row["Rate of Semi-Industry Revenue"],
            "customer_sector": row["customer_sector"],
            "customer_industry": row["customer_industry"],
            "customer_country": row["customer_country"],
            "customer_employees": row["customer_employees"],
            "customer_mkt_cap_category": row["customer_mkt_cap_category"]
        }
        rows.append(new_row)

for row in rows:
    sql = "INSERT INTO semi_industry_supply_chain_relationships (created_date, supplier_name, supplier_ticker, supplier_sector, supplier_industry, supplier_country, supplier_employees, supplier_mkt_cap_category, customer_name, customer_ticker, rate_of_semi_industry_revenue, customer_sector, customer_industry, customer_country, customer_employees, customer_mkt_cap_category) "
    sql += "VALUES "
    sql += "(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    cs.execute(sql, (row["created_date"], row["supplier_name"], row["supplier_ticker"], row["supplier_sector"], row["supplier_industry"], row["supplier_country"], row["supplier_employees"], row["supplier_mkt_cap_category"], row["customer_name"], row["customer_ticker"], row["rate_of_semi_industry_revenue"], row["customer_sector"], row["customer_industry"], row["customer_country"], row["customer_employees"], row["customer_mkt_cap_category"]))
    conn.commit()

# %% [markdown]
# Analysis

# %%
# import jinja2
# raw_query = """
#     SELECT 
#     symbol,
#     companyName,
#     market_cap_category,
#     ipoDate,
#     country,
#     sector,
#     industry,
#     fullTimeEmployees,
#     description
#     
#     FROM 'sp500_company_info.csv'
#     
#     -- WHERE industry LIKE '%Semiconductor%'
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT CURRENT_DATE() as date, semireturns.symbol, semici.companyName, semici.fullTimeEmployees, semici.market_cap_category, semici.country, semireturns.total_return, semireturns.capital_gain_return, semireturns.dividend_return,
#     
#     CASE 
#         WHEN semireturns.start_date <= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '365 days') 
#              AND semireturns.start_date >= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '405 days') THEN '1yr_return'
#         WHEN semireturns.start_date <= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '406 days') 
#              AND semireturns.start_date >= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '2000 days') THEN '5yr_return'
#         WHEN semireturns.start_date <= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '2001 days') 
#              AND semireturns.start_date >= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '4000 days') THEN '10yr_return'
#         WHEN semireturns.start_date <= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '4001 days') 
#              AND semireturns.start_date >= DATE_TRUNC('day', CURRENT_DATE - INTERVAL '10000 days') THEN '20yr_return'
#         ELSE 'Other'
#       END AS time_period_returns
#     
#     FROM company_info as semici
#     JOIN 'sp500_returns.csv' as semireturns
#     ON semici.symbol = semireturns.symbol
#     GROUP BY date, semireturns.symbol, semici.companyName, semici.fullTimeEmployees, semici.market_cap_category, semici.country, time_period_returns, semireturns.total_return, semireturns.capital_gain_return, semireturns.dividend_return;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select * from returns_by_period where time_period_returns = '20yr_return'
#     ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select * from returns_by_period where time_period_returns = '10yr_return'
#     ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select * from returns_by_period where time_period_returns = '5yr_return'
#     ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select * from returns_by_period where time_period_returns = '1yr_return'
#     ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT km.symbol, 
#     km.date, 
#     ROUND(MAX(km.revenuePerShare),2) as revenuePerShare, 
#     ROUND(MAX(km.evToSales), 2) as evToSales, 
#     ROUND(MAX(km.stockBasedCompensationToRevenue), 2) as stockBasedCompensationToRevenue, 
#     ROUND(MAX(km.researchAndDdevelopementToRevenue), 2) as researchAndDdevelopementToRevenue, 
#     ROUND(MAX(kr.priceToSalesRatio), 2) as priceToSalesRatio, 
#     ROUND(MAX(kr.grossProfitMargin), 2) as grossProfitMargin
#     
#     FROM 'sp500_metrics.csv' as km
#     JOIN 'sp500_ratios.csv' as kr
#     ON km.symbol = kr.symbol
#     GROUP BY km.symbol, km.date;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT Ticker,
#            ROUND(AVG(revenueGrowth), 2) AS avg_revenueGrowth,
#            ROUND(AVG(grossProfitGrowth), 2) AS avg_grossProfitGrowth,
#            ROUND(AVG(ebitgrowth), 2) AS avg_ebitgrowth,
#            ROUND(AVG(operatingIncomeGrowth), 2) AS avg_operatingIncomeGrowth,
#            ROUND(AVG(freeCashFlowGrowth), 2) AS avg_freeCashFlowGrowth,
#            ROUND(AVG(epsdilutedGrowth), 2) AS avg_epsdilutedGrowth,
#            ROUND(AVG(netIncomeGrowth), 2) AS avg_netIncomeGrowth,
#            ROUND(AVG(debtGrowth), 2) AS avg_debtGrowth,
#            ROUND(AVG(inventoryGrowth), 2) AS avg_inventoryGrowth,
#            ROUND(AVG(sgaexpensesGrowth), 2) AS avg_sgaexpensesGrowth,
#            ROUND(AVG(assetGrowth), 2) AS avg_assetGrowth,
#            ROUND(AVG(rdexpenseGrowth), 2) AS avg_rdexpenseGrowth,
#            ROUND(AVG(dividendsperShareGrowth), 2) AS avg_dividendsperShareGrowth,
#            ROUND(AVG(weightedAverageSharesDilutedGrowth), 2) AS avg_weightedAverageSharesDilutedGrowth
#     FROM (
#       SELECT Ticker,
#              revenueGrowth,
#              grossProfitGrowth,
#              ebitgrowth,
#              operatingCashFlowGrowth,
#              operatingIncomeGrowth,
#              freeCashFlowGrowth,
#              epsdilutedGrowth,
#              netIncomeGrowth,
#              debtGrowth,
#              inventoryGrowth,
#              sgaexpensesGrowth,
#              assetGrowth,
#              rdexpenseGrowth,
#              dividendsperShareGrowth,
#              weightedAverageSharesDilutedGrowth,
#              ROW_NUMBER() OVER (PARTITION BY Ticker ORDER BY date DESC) AS row_num
#       FROM financial_statement_growth 
#     ) subquery
#     WHERE row_num <= 3
#     GROUP BY Ticker;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT t.*
#     FROM (
#         SELECT *, ROW_NUMBER() OVER (PARTITION BY Ticker ORDER BY date DESC) AS row_num
#         FROM financial_statement_growth
#     ) t
#     WHERE t.row_num <= 2;
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT 
#       t1.Ticker, t1.Period, 
#       ROUND(t1.RevenueGrowth - t2.RevenueGrowth, 2) AS RevenueGrowthYoY,
#       ROUND(t1.GrossProfitGrowth - t2.GrossProfitGrowth, 2) AS GrossProfitGrowthYoY, 
#       ROUND(t1.EBITGrowth - t2.EBITGrowth, 2) AS EBITGrowthYoY,
#       ROUND(t1.OperatingIncomeGrowth - t2.OperatingIncomeGrowth, 2) AS OperatingIncomeGrowthYoY,
#       ROUND(t1.NetIncomeGrowth - t2.NetIncomeGrowth, 2) AS NetIncomeGrowthYoY,
#       ROUND(t1.EPSGrowth - t2.EPSGrowth, 2) AS EPSGrowthYoY, 
#       ROUND(t1.EPSDilutedGrowth - t2.EPSDilutedGrowth, 2) AS EPSDilutedGrowthYoY,
#       ROUND(t1.WeightedAverageSharesGrowth - t2.WeightedAverageSharesGrowth, 2) AS WeightedAverageSharesGrowthYoY,
#       ROUND(t1.WeightedAverageSharesDilutedGrowth - t2.WeightedAverageSharesDilutedGrowth, 2) AS WeightedAverageSharesDilutedGrowthYoY,
#       ROUND(t1.DividendsPerShareGrowth - t2.DividendsPerShareGrowth, 2) AS DividendsPerShareGrowthYoY  
#     FROM two_years_financial_growth_values t1
#     JOIN two_years_financial_growth_values t2  
#        ON t1.Ticker = t2.Ticker 
#        AND t1.Period = t2.Period 
#        AND t2.Date = (SELECT MAX(Date) FROM two_years_financial_growth_values t3 
#                              WHERE t3.Ticker = t1.Ticker 
#                              AND t3.Period = t1.Period 
#                              AND t3.Date < t1.Date)
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %% [markdown]
# Get Full Financials From Stock Analysis

# %% [markdown]
# Companies Covered Overview

# %%
# import jinja2
# raw_query = """
#     SELECT symbol, market_cap_category, companyName, industry, sector, country, ipoDate, description 
#     FROM sp500 _company_info.csv
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
company_info

# %% [markdown]
# Returns

# %%
import altair
chart_returns_20yr = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            },
                            "params": [
                                {
                                    "name": "interval_intervalselection_",
                                    "select": {
                                        "type": "interval",
                                        "encodings": [
                                            "x",
                                            "y"
                                        ],
                                        "translate": false,
                                        "zoom": false,
                                        "mark": {
                                            "fill": "#669EFF",
                                            "fillOpacity": 0.07,
                                            "stroke": "#669EFF",
                                            "strokeOpacity": 0.4
                                        }
                                    }
                                },
                                {
                                    "name": "legend_pointselection_",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend"
                                }
                            ]
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "field": "symbol",
                                                "oneOf": [
                                                    "KERN"
                                                ]
                                            },
                                            {
                                                "field": "total_return",
                                                "range": [
                                                    -0.22666666666666613,
                                                    -0.1644444444444435
                                                ]
                                            },
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": {
                                "symbolOpacity": 1
                            },
                            "title": "market_cap_category"
                        },
                        "opacity": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "field": "symbol",
                                                "oneOf": [
                                                    "KERN"
                                                ]
                                            },
                                            {
                                                "field": "total_return",
                                                "range": [
                                                    -0.22666666666666613,
                                                    -0.1644444444444435
                                                ]
                                            },
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": 0.22499999999999998
                            },
                            "value": 0.75
                        },
                        "size": {
                            "value": 100
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "field": "symbol",
                                                "oneOf": [
                                                    "KERN"
                                                ]
                                            },
                                            {
                                                "field": "total_return",
                                                "range": [
                                                    -0.22666666666666613,
                                                    -0.1644444444444435
                                                ]
                                            },
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": null,
                            "title": "market_cap_category"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "total_return",
                                "type": "quantitative",
                                "title": "total_return"
                            },
                            {
                                "field": "market_cap_category"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 200
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "market_cap_category"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_color_spec_1a46f64b_da01_4f8c_a1c8_ec5a8f635bbb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "name": "__drilldown_dataset",
                    "mark": {
                        "type": "point",
                        "opacity": 0
                    },
                    "transform": [
                        {
                            "filter": {
                                "param": "interval_intervalselection_"
                            }
                        },
                        {
                            "filter": "indexof([\"KERN\"], datum[\"symbol\"]) !== -1"
                        },
                        {
                            "filter": "-0.22666666666666613 <= datum[\"total_return\"] && datum[\"total_return\"] <= -0.1644444444444435"
                        },
                        {
                            "filter": {
                                "param": "legend_pointselection_"
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "legend_pointselection_": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        }
    }
}
""")
chart_returns_20yr.datasets.layer00 = returns_20yr.to_json(orient='records')
chart_returns_20yr.display(actions=False)

# %%
import altair
chart_returns_10yr = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            },
                            "params": [
                                {
                                    "name": "interval_intervalselection_",
                                    "select": {
                                        "type": "interval",
                                        "encodings": [
                                            "x",
                                            "y"
                                        ],
                                        "translate": false,
                                        "zoom": false,
                                        "mark": {
                                            "fill": "#669EFF",
                                            "fillOpacity": 0.07,
                                            "stroke": "#669EFF",
                                            "strokeOpacity": 0.4
                                        }
                                    }
                                },
                                {
                                    "name": "legend_pointselection_",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend",
                                    "value": []
                                }
                            ]
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": {
                                "symbolOpacity": 1
                            },
                            "title": "market_cap_category"
                        },
                        "opacity": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": 0.22499999999999998
                            },
                            "value": 0.75
                        },
                        "size": {
                            "value": 100
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": null,
                            "title": "market_cap_category"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "total_return",
                                "type": "quantitative",
                                "title": "total_return"
                            },
                            {
                                "field": "market_cap_category"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 200
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "market_cap_category"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_color_spec_1a46f64b_da01_4f8c_a1c8_ec5a8f635bbb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "name": "__drilldown_dataset",
                    "mark": {
                        "type": "point",
                        "opacity": 0
                    },
                    "transform": [
                        {
                            "filter": {
                                "param": "interval_intervalselection_"
                            }
                        },
                        {
                            "filter": {
                                "param": "legend_pointselection_"
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "legend_pointselection_": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        }
    }
}
""")
chart_returns_10yr.datasets.layer00 = returns_10yr.to_json(orient='records')
chart_returns_10yr.display(actions=False)

# %%
import altair
chart_returns_5yr = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            },
                            "params": [
                                {
                                    "name": "interval_intervalselection_",
                                    "select": {
                                        "type": "interval",
                                        "encodings": [
                                            "x",
                                            "y"
                                        ],
                                        "translate": false,
                                        "zoom": false,
                                        "mark": {
                                            "fill": "#669EFF",
                                            "fillOpacity": 0.07,
                                            "stroke": "#669EFF",
                                            "strokeOpacity": 0.4
                                        }
                                    }
                                },
                                {
                                    "name": "legend_pointselection_",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend",
                                    "value": []
                                }
                            ]
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": {
                                "symbolOpacity": 1
                            },
                            "title": "market_cap_category"
                        },
                        "opacity": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": 0.22499999999999998
                            },
                            "value": 0.75
                        },
                        "size": {
                            "value": 100
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": null,
                            "title": "market_cap_category"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "total_return",
                                "type": "quantitative",
                                "title": "total_return"
                            },
                            {
                                "field": "market_cap_category"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 200
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "market_cap_category"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_color_spec_1a46f64b_da01_4f8c_a1c8_ec5a8f635bbb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "name": "__drilldown_dataset",
                    "mark": {
                        "type": "point",
                        "opacity": 0
                    },
                    "transform": [
                        {
                            "filter": {
                                "param": "interval_intervalselection_"
                            }
                        },
                        {
                            "filter": {
                                "param": "legend_pointselection_"
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "legend_pointselection_": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        }
    }
}
""")
chart_returns_5yr.datasets.layer00 = returns_5yr.to_json(orient='records')
chart_returns_5yr.display(actions=False)

# %%
import altair
chart_returns_1yr = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            },
                            "params": [
                                {
                                    "name": "interval_intervalselection_",
                                    "select": {
                                        "type": "interval",
                                        "encodings": [
                                            "x",
                                            "y"
                                        ],
                                        "translate": false,
                                        "zoom": false,
                                        "mark": {
                                            "fill": "#669EFF",
                                            "fillOpacity": 0.07,
                                            "stroke": "#669EFF",
                                            "strokeOpacity": 0.4
                                        }
                                    }
                                },
                                {
                                    "name": "legend_pointselection_",
                                    "select": {
                                        "type": "point",
                                        "encodings": [
                                            "color"
                                        ]
                                    },
                                    "bind": "legend"
                                }
                            ]
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": {
                                "symbolOpacity": 1
                            },
                            "title": "market_cap_category"
                        },
                        "opacity": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": 0.22499999999999998
                            },
                            "value": 0.75
                        },
                        "size": {
                            "value": 100
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "-y"
                        },
                        "y": {
                            "field": "total_return",
                            "type": "quantitative",
                            "title": "total_return",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "condition": {
                                "test": {
                                    "not": {
                                        "and": [
                                            {
                                                "param": "legend_pointselection_"
                                            }
                                        ]
                                    },
                                    "empty": false
                                },
                                "value": "grey"
                            },
                            "field": "market_cap_category",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#F58518",
                                    "#9D755D",
                                    "#E45756",
                                    "#BAB0AC",
                                    "#FF9DA6",
                                    "#4C78A8",
                                    "#72B7B2",
                                    "#EECA3B",
                                    "#B279A2"
                                ]
                            },
                            "sort": [
                                "Mid-cap",
                                "Mega-cap",
                                "Nano-cap",
                                "Large-cap",
                                "Micro-cap",
                                "Small-cap"
                            ],
                            "legend": null,
                            "title": "market_cap_category"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "total_return",
                                "type": "quantitative",
                                "title": "total_return"
                            },
                            {
                                "field": "market_cap_category"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 200
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_1a46f64b-da01-4f8c-a1c8-ec5a8f635bbb",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "market_cap_category"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_color_spec_1a46f64b_da01_4f8c_a1c8_ec5a8f635bbb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "name": "__drilldown_dataset",
                    "mark": {
                        "type": "point",
                        "opacity": 0
                    },
                    "transform": [
                        {
                            "filter": {
                                "param": "interval_intervalselection_"
                            }
                        },
                        {
                            "filter": {
                                "param": "legend_pointselection_"
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "legend_pointselection_": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        }
    }
}
""")
chart_returns_1yr.datasets.layer00 = returns_1yr.to_json(orient='records')
chart_returns_1yr.display(actions=False)

# %% [markdown]
# DCF

# %%
import altair
chart_dcf_delta = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "dcf_to_price_delta_rate",
                                        "type": "quantitative",
                                        "aggregate": "average",
                                        "title": "Average of dcf_to_price_delta_rate"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"average_dcf_to_price_delta_rate\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"average_dcf_to_price_delta_rate\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"average_dcf_to_price_delta_rate\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "dcf_to_price_delta_rate",
                                    "aggregate": "average",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "dcf_to_price_delta_rate",
                                    "type": "quantitative",
                                    "aggregate": "average",
                                    "title": "Average of dcf_to_price_delta_rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "dcf_to_price_delta_rate",
                            "type": "quantitative",
                            "aggregate": "average",
                            "title": "Average of dcf_to_price_delta_rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_3397f867_401e_44fb_9473_b18e16be0070",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_dcf_delta.datasets.layer00 = dcf_delta.to_json(orient='records')
chart_dcf_delta.display(actions=False)

# %%
import altair
chart_recent_year_dcf_delta = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "dcf_to_price_delta_rate",
                                        "type": "quantitative",
                                        "title": "dcf_to_price_delta_rate"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"dcf_to_price_delta_rate\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"dcf_to_price_delta_rate\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"dcf_to_price_delta_rate\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "dcf_to_price_delta_rate",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "dcf_to_price_delta_rate",
                                    "type": "quantitative",
                                    "title": "dcf_to_price_delta_rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "dcf_to_price_delta_rate",
                            "type": "quantitative",
                            "title": "dcf_to_price_delta_rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_db256d8a_4ce0_44bc_8c7e_8a87761ccab5",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_dcf_delta.datasets.layer00 = recent_year_dcf_delta.to_json(orient='records')
chart_recent_year_dcf_delta.display(actions=False)

# %% [markdown]
# Financial Statements Growth

# %%
import pandas as pd

# Read the CSV data
df = pd.read_csv('semi_supply_chain_SemiEM_financial_statement_growth.csv')   

# Group the data by Ticker  
grouped = df.groupby('Ticker')    

# Get the most recent date for each Ticker
max_dates = grouped.date.max()

# Merge this to the original data to get only the rows with the most recent date per Ticker
df = pd.merge(df, max_dates.reset_index(), on=['Ticker', 'date'])

# Filter to just the columns we want
df = df[['Ticker', 'date',   
               'revenueGrowth', 'grossProfitGrowth', 
               'freeCashFlowGrowth', 'operatingCashFlowGrowth']]  

# Reset the index
df_recent_year_growth = df.reset_index(drop=True)   

# final_df = most_recent 

print(df_recent_year_growth.head())

# %%
# import jinja2
# raw_query = """
#     SELECT Ticker, substr(df_recent_year_growth.date, 1, 4) as most_recent_year,   
#       ROUND(revenueGrowth, 2) as revenueGrowth,   
#       ROUND(grossProfitGrowth, 2) as grossProfitGrowth, 
#       ROUND(freeCashFlowGrowth, 2) as freeCashFlowGrowth,
#       ROUND(operatingCashFlowGrowth, 2) as operatingCashFlowGrowth   
#     FROM df_recent_year_growth  
#     WHERE df_recent_year_growth.date IN   
#      (SELECT MAX(t2.date) FROM df_recent_year_growth t2  
#                        WHERE df_recent_year_growth.Ticker = t2.Ticker)
#     GROUP BY Ticker, most_recent_year, revenueGrowth, grossProfitGrowth, freeCashFlowGrowth, operatingCashFlowGrowth
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_recent_year_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "revenueGrowth",
                                        "type": "quantitative",
                                        "title": "revenueGrowth"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"revenueGrowth\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"revenueGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"revenueGrowth\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "revenueGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "revenueGrowth",
                                    "type": "quantitative",
                                    "title": "revenueGrowth",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            },
                            "sort": "ascending"
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_5111df9a_5d04_41c4_bcdf_bee61480d919",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_financial_growth.datasets.layer00 = recent_year_financial_growth.to_json(orient='records')
chart_recent_year_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_revenueGrowth",
                                        "type": "quantitative",
                                        "aggregate": "sum",
                                        "title": "Sum of avg_revenueGrowth"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"sum_avg_revenueGrowth\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_avg_revenueGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_avg_revenueGrowth\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_revenueGrowth",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_revenueGrowth",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of avg_revenueGrowth",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "Sum of avg_revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_23bc68fc_6fa5_4a19_8501_03980c2a98eb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_yoy_financial_growth_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "RevenueGrowthYoY",
                                        "type": "quantitative",
                                        "aggregate": "sum",
                                        "title": "Sum of RevenueGrowthYoY"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"sum_RevenueGrowthYoY\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_RevenueGrowthYoY\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_RevenueGrowthYoY\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "RevenueGrowthYoY",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "RevenueGrowthYoY",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of RevenueGrowthYoY",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "RevenueGrowthYoY",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "Sum of RevenueGrowthYoY",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_23bc68fc_6fa5_4a19_8501_03980c2a98eb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_yoy_financial_growth_metrics.datasets.layer00 = yoy_financial_growth_metrics.to_json(orient='records')
chart_yoy_financial_growth_metrics.display(actions=False)

# %%
import altair
chart_recent_year_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "grossProfitGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "grossProfitGrowth",
                            "type": "quantitative",
                            "title": "grossProfitGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "grossProfitGrowth",
                            "scale": {
                                "range": [
                                    "#654A94",
                                    "#654A94"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_5111df9a_5d04_41c4_bcdf_bee61480d919",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "revenueGrowth",
                            "scale": {
                                "range": [
                                    "#00B3A4",
                                    "#00B3A4"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#00B3A4"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_financial_growth.datasets.layer00 = recent_year_financial_growth.to_json(orient='records')
chart_recent_year_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_grossProfitGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"avg_grossProfitGrowth\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_grossProfitGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_grossProfitGrowth\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_grossProfitGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_grossProfitGrowth",
                                    "type": "quantitative",
                                    "title": "Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_grossProfitGrowth",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_grossProfitGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_9a74c7dd_03bc_412d_9b72_216e12c2d3bb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_revenueGrowth",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_e0f9c061-cfb2-462a-ba95-6265ba1596b9",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_e0f9c061-cfb2-462a-ba95-6265ba1596b9",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_yoy_financial_growth_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "GrossProfitGrowthYoY",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"GrossProfitGrowthYoY\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"GrossProfitGrowthYoY\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"GrossProfitGrowthYoY\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "GrossProfitGrowthYoY",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "GrossProfitGrowthYoY",
                                    "type": "quantitative",
                                    "title": "Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "GrossProfitGrowthYoY",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "GrossProfitGrowthYoY",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_9a74c7dd_03bc_412d_9b72_216e12c2d3bb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "RevenueGrowthYoY",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "RevenueGrowthYoY",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "RevenueGrowthYoY",
                            "type": "quantitative",
                            "title": "Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "RevenueGrowthYoY",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_e0f9c061-cfb2-462a-ba95-6265ba1596b9",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_e0f9c061-cfb2-462a-ba95-6265ba1596b9",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_yoy_financial_growth_metrics.datasets.layer00 = yoy_financial_growth_metrics.to_json(orient='records')
chart_yoy_financial_growth_metrics.display(actions=False)

# %%
import altair
chart_recent_year_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "freeCashFlowGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "freeCashFlowGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#654A94",
                                    "#654A94"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_5111df9a_5d04_41c4_bcdf_bee61480d919",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "revenueGrowth",
                            "scale": {
                                "range": [
                                    "#00B3A4",
                                    "#00B3A4"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#00B3A4"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "grossProfitGrowth",
                            "type": "quantitative",
                            "title": "grossProfitGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "grossProfitGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "grossProfitGrowth",
                            "type": "quantitative",
                            "title": "grossProfitGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#4C78A8"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "grossProfitGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_937aab5c-9e03-4a12-8392-22ffc63c5fde",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_937aab5c-9e03-4a12-8392-22ffc63c5fde",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_financial_growth.datasets.layer00 = recent_year_financial_growth.to_json(orient='records')
chart_recent_year_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_freeCashFlowGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "avg_freeCashFlowGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#654A94",
                                    "#654A94"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_5111df9a_5d04_41c4_bcdf_bee61480d919",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "avg_revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_revenueGrowth",
                            "scale": {
                                "range": [
                                    "#00B3A4",
                                    "#00B3A4"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "avg_revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#00B3A4"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_ccfb196f-70da-46a8-8953-0aceb3586d54",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_grossProfitGrowth",
                            "type": "quantitative",
                            "title": "avg_grossProfitGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_grossProfitGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_grossProfitGrowth",
                            "type": "quantitative",
                            "title": "avg_grossProfitGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#4C78A8"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_grossProfitGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_937aab5c-9e03-4a12-8392-22ffc63c5fde",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_937aab5c-9e03-4a12-8392-22ffc63c5fde",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_recent_year_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "operatingCashFlowGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"operatingCashFlowGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"operatingCashFlowGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"operatingCashFlowGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "operatingCashFlowGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "operatingCashFlowGrowth",
                                    "type": "quantitative",
                                    "title": "operatingCashFlowGrowth",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "operatingCashFlowGrowth",
                            "type": "quantitative",
                            "title": "operatingCashFlowGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "operatingCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_85c52a2a_788f_4aa1_829c_6d2b9cb78868",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "revenueGrowth",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenueGrowth",
                            "type": "quantitative",
                            "title": "revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_7e76ab62-a628-422f-afee-cc350bcec1c9",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_7e76ab62-a628-422f-afee-cc350bcec1c9",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_financial_growth.datasets.layer00 = recent_year_financial_growth.to_json(orient='records')
chart_recent_year_financial_growth.display(actions=False)

# %%
import altair
chart_yoy_financial_growth_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "OperatingIncomeGrowthYoY",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"OperatingIncomeGrowthYoY\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"OperatingIncomeGrowthYoY\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"OperatingIncomeGrowthYoY\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "OperatingIncomeGrowthYoY",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "OperatingIncomeGrowthYoY",
                                    "type": "quantitative",
                                    "title": "OperatingIncomeGrowthYoY",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "OperatingIncomeGrowthYoY",
                            "type": "quantitative",
                            "title": "OperatingIncomeGrowthYoY",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "OperatingIncomeGrowthYoY",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_85c52a2a_788f_4aa1_829c_6d2b9cb78868",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "RevenueGrowthYoY",
                            "type": "quantitative",
                            "title": "RevenueGrowthYoY",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "RevenueGrowthYoY",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "RevenueGrowthYoY",
                            "type": "quantitative",
                            "title": "RevenueGrowthYoY",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "RevenueGrowthYoY",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_7e76ab62-a628-422f-afee-cc350bcec1c9",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_7e76ab62-a628-422f-afee-cc350bcec1c9",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_yoy_financial_growth_metrics.datasets.layer00 = yoy_financial_growth_metrics.to_json(orient='records')
chart_yoy_financial_growth_metrics.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_operatingIncomeGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_operatingIncomeGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_operatingIncomeGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_operatingIncomeGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_operatingIncomeGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_operatingIncomeGrowth",
                                    "type": "quantitative",
                                    "title": "avg_operatingIncomeGrowth",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_operatingIncomeGrowth",
                            "type": "quantitative",
                            "title": "avg_operatingIncomeGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_operatingIncomeGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_85c52a2a_788f_4aa1_829c_6d2b9cb78868",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "avg_revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_revenueGrowth",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "avg_revenueGrowth",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_f65ccc4c-ece8-42f1-9e03-19c393148672",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_f65ccc4c-ece8-42f1-9e03-19c393148672",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_epsdilutedGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_epsdilutedGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_epsdilutedGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_epsdilutedGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_epsdilutedGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_epsdilutedGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_epsdilutedGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_epsdilutedGrowth",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#54A24B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_dividendsperShareGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_dividendsperShareGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_dividendsperShareGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_dividendsperShareGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_dividendsperShareGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_dividendsperShareGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_dividendsperShareGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_dividendsperShareGrowth",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#54A24B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_weightedAverageSharesDilutedGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_weightedAverageSharesDilutedGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_weightedAverageSharesDilutedGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_weightedAverageSharesDilutedGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_weightedAverageSharesDilutedGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_weightedAverageSharesDilutedGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_weightedAverageSharesDilutedGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_weightedAverageSharesDilutedGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_debtGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_debtGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_debtGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_debtGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_debtGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_debtGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_debtGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_debtGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_inventoryGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_inventoryGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_inventoryGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_inventoryGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_inventoryGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_inventoryGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_inventoryGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_inventoryGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_revenueGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_sgaexpensesGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_sgaexpensesGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_sgaexpensesGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_sgaexpensesGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_sgaexpensesGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_sgaexpensesGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_sgaexpensesGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_sgaexpensesGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_revenueGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_revenueGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_revenueGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_rdexpenseGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_rdexpenseGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_rdexpenseGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_rdexpenseGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_rdexpenseGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_rdexpenseGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_rdexpenseGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_rdexpenseGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
import altair
chart_t3_year_average_financial_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "Ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "avg_assetGrowth",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"avg_assetGrowth\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"avg_assetGrowth\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"avg_assetGrowth\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "avg_assetGrowth",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "avg_assetGrowth",
                                    "type": "quantitative",
                                    "title": "Avg Growth Rate",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_assetGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_assetGrowth",
                            "scale": {
                                "range": [
                                    "#9D755D",
                                    "#9D755D"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_dedfedff_7855_4a31_bee2_f5c79ab78810",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "avg_freeCashFlowGrowth",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "avg_freeCashFlowGrowth",
                            "type": "quantitative",
                            "title": "Avg Growth Rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "avg_freeCashFlowGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_50e43ad8-2691-46e2-983c-1aa234494393",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_t3_year_average_financial_growth.datasets.layer00 = t3_year_average_financial_growth.to_json(orient='records')
chart_t3_year_average_financial_growth.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     SELECT 
#     Ticker, 
#     date as most_recent_year, 
#     ROUND(tenYRevenueGrowthPerShare, 2) as tenYRevenueGrowthPerShare,  
#     ROUND(tenYOperatingCFGrowthPerShare, 2) as tenYOperatingCFGrowthPerShare,
#     ROUND(tenYNetIncomeGrowthPerShare, 2) as tenYNetIncomeGrowthPerShare,
#     ROUND(tenYShareholdersEquityGrowthPerShare, 2) as tenYShareholdersEquityGrowthPerShare,
#     ROUND(tenYDividendperShareGrowthPerShare, 2) as tenYDividendperShareGrowthPerShare
#     
#     from financial_statement_growth 
#     
#     WHERE date > (CURRENT_DATE - INTERVAL '1 year')
#     
#     GROUP BY 
#     Ticker,
#     date,
#     tenYRevenueGrowthPerShare,  
#     tenYOperatingCFGrowthPerShare,
#     tenYNetIncomeGrowthPerShare,
#     tenYShareholdersEquityGrowthPerShare,
#     tenYDividendperShareGrowthPerShare
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_ten_yr_performance_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYRevenueGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "tenYRevenueGrowthPerShare",
                            "scale": {
                                "range": [
                                    "#B279A2",
                                    "#B279A2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYRevenueGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#B279A2"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "tenYRevenueGrowthPerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYOperatingCFGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "tenYOperatingCFGrowthPerShare",
                            "scale": {
                                "range": [
                                    "#72B7B2",
                                    "#72B7B2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYOperatingCFGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#72B7B2"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "tenYOperatingCFGrowthPerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_25ed90cc-06f4-4506-8cc4-68548b278374",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_25ed90cc-06f4-4506-8cc4-68548b278374",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_ten_yr_performance_growth.datasets.layer00 = ten_yr_performance_growth.to_json(orient='records')
chart_ten_yr_performance_growth.display(actions=False)

# %%
import altair
chart_ten_yr_performance_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYNetIncomeGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "tenYNetIncomeGrowthPerShare",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYNetIncomeGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {},
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "tenYNetIncomeGrowthPerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYDividendperShareGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "tenYDividendperShareGrowthPerShare",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYDividendperShareGrowthPerShare",
                            "type": "quantitative",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "tenYDividendperShareGrowthPerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_25ed90cc-06f4-4506-8cc4-68548b278374",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_25ed90cc-06f4-4506-8cc4-68548b278374",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_ten_yr_performance_growth.datasets.layer00 = ten_yr_performance_growth.to_json(orient='records')
chart_ten_yr_performance_growth.display(actions=False)

# %%
import altair
chart_ten_yr_performance_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYShareholdersEquityGrowthPerShare",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#4C78A8"
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "tenYShareholdersEquityGrowthPerShare",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "Performance",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#4C78A8"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "tenYShareholdersEquityGrowthPerShare",
                                "type": "quantitative",
                                "aggregate": "sum",
                                "title": "Performance"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_fbd11282-1d28-48a1-bc48-4dea40f73081",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_ten_yr_performance_growth.datasets.layer00 = ten_yr_performance_growth.to_json(orient='records')
chart_ten_yr_performance_growth.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     SELECT 
#     Ticker, 
#     date as most_recent_year, 
#     ROUND(sgaexpensesGrowth, 2) as sgaexpensesGrowth,  
#     ROUND(rdexpenseGrowth, 2) as rdexpenseGrowth,
#     ROUND(debtGrowth, 2) as debtGrowth,
#     ROUND(assetGrowth,2) as assetGrowth,
#     ROUND(inventoryGrowth, 2) as inventoryGrowth
#     
#     from financial_statement_growth 
#     
#     WHERE date > (CURRENT_DATE - INTERVAL '1 year')
#     
#     GROUP BY 
#     Ticker,
#     date,
#     sgaexpensesGrowth,  
#     rdexpenseGrowth,
#     debtGrowth,
#     assetGrowth,
#     inventoryGrowth
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_recent_year_below_the_line_growth = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "shape": "circle",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "sgaexpensesGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "sgaexpensesGrowth",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "shape": "circle",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "sgaexpensesGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#F58518"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "sgaexpensesGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_02e37007-cee5-4d7c-bf22-f1d407486764",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_02e37007-cee5-4d7c-bf22-f1d407486764",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "rdexpenseGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "rdexpenseGrowth",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "rdexpenseGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#4C78A8"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "rdexpenseGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_ac9ad7b0-29e7-41d1-a522-fe446250a9a5",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_ac9ad7b0-29e7-41d1-a522-fe446250a9a5",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "debtGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "debtGrowth",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "debtGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "debtGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_0bfc00ec-6b6e-4054-a2cd-0f7d243449cc",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_0bfc00ec-6b6e-4054-a2cd-0f7d243449cc",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "assetGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "assetGrowth",
                            "scale": {
                                "range": [
                                    "#72B7B2",
                                    "#72B7B2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "assetGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#72B7B2"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "assetGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_d8984ae3-10e3-4315-b559-7cd81ec6d4c7",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_d8984ae3-10e3-4315-b559-7cd81ec6d4c7",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "inventoryGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "inventoryGrowth",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#54A24B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        },
                        "size": {
                            "value": 80
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "Ticker",
                            "type": "ordinal",
                            "title": "Ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "inventoryGrowth",
                            "type": "quantitative",
                            "title": "Growth rate",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#54A24B"
                        },
                        "tooltip": [
                            {
                                "field": "Ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "inventoryGrowth",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_3cd5bed6-9186-474b-9606-672496a8e161",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 160
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_3cd5bed6-9186-474b-9606-672496a8e161",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_below_the_line_growth.datasets.layer00 = recent_year_below_the_line_growth.to_json(orient='records')
chart_recent_year_below_the_line_growth.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     select 
#     symbol,
#     MAX(date) as recent_year_date,
#     ROUND((marketCap / enterpriseValue),2) as marketcap_to_EV_ratio
#     
#     from "semi_supply_chain_SemiEM_metrics.csv"
#     
#     WHERE date > (CURRENT_DATE - INTERVAL '1 year')
#     
#     GROUP BY
#     symbol,
#     date,
#     marketCap,
#     enterpriseValue
#      ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_mktcap_to_ev_ratio = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "marketcap_to_EV_ratio",
                                        "type": "quantitative",
                                        "aggregate": "sum",
                                        "title": "Sum of marketcap_to_EV_ratio"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#EECA3B",
                                "dy": {
                                    "expr": "datum[\"sum_marketcap_to_EV_ratio\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_marketcap_to_EV_ratio\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_marketcap_to_EV_ratio\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "marketcap_to_EV_ratio",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "marketcap_to_EV_ratio",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of marketcap_to_EV_ratio",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "marketcap_to_EV_ratio",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "Sum of marketcap_to_EV_ratio",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#BAB0AC"
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_63e02cfc_b3c6_4a25_8c4a_4fcaf7df4802",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_mktcap_to_ev_ratio.datasets.layer00 = mktcap_to_ev_ratio.to_json(orient='records')
chart_mktcap_to_ev_ratio.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     select 
#     symbol,
#     MAX(date) as recent_year_date,
#     ROUND(revenuePerShare, 2) as revenuePerShare,
#     ROUND(netIncomePerShare, 2) as netIncomePerShare,
#     ROUND(operatingCashFlowPerShare, 2) as operatingCashFlowPerShare,
#     ROUND(peRatio, 2) as peRatio,
#     ROUND(priceToSalesRatio, 2) as priceToSalesRatio,
#     ROUND(roic, 2) as roic,
#     ROUND(roe, 2) as roe,
#     
#     from "semi_supply_chain_SemiEM_metrics.csv"
#     
#     WHERE date > (CURRENT_DATE - INTERVAL '1 year')
#     AND symbol != 'UNIT'
#     
#     GROUP BY
#     symbol,
#     revenuePerShare,
#     netIncomePerShare,
#     operatingCashFlowPerShare,
#     revenuePerShare,
#     peRatio,
#     priceToSalesRatio,
#     roic,
#     roe
#      ;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_recent_year_value_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"peRatio\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"peRatio\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"peRatio\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "peRatio",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "peRatio",
                                    "type": "quantitative",
                                    "title": "peRatio",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "peRatio",
                            "type": "quantitative",
                            "title": "peRatio",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "peRatio",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_1c8b887e_150b_4b66_9c83_11595b9de9dc",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"priceToSalesRatio\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"priceToSalesRatio\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"priceToSalesRatio\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "priceToSalesRatio",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "priceToSalesRatio",
                                    "type": "quantitative",
                                    "title": "priceToSalesRatio",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "priceToSalesRatio",
                            "type": "quantitative",
                            "title": "priceToSalesRatio",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "priceToSalesRatio",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_94144bec_e1c0_4f17_969c_98dd01e659dd",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "peRatio",
                                        "type": "quantitative"
                                    },
                                    {
                                        "field": "priceToSalesRatio",
                                        "type": "quantitative"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_value_metrics.datasets.layer00 = recent_year_value_metrics.to_json(orient='records')
chart_recent_year_value_metrics.display(actions=False)

# %%
import altair
chart_recent_year_value_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "line",
                                "point": false,
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "point",
                                "tooltip": false
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 0,
                                    "condition": {
                                        "param": "shared_pivot_hover_param",
                                        "value": 1,
                                        "empty": false
                                    }
                                },
                                "size": {
                                    "value": 80
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "-5"
                                },
                                "dx": {
                                    "expr": "0"
                                },
                                "baseline": {
                                    "expr": "'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "roic",
                                    "type": "quantitative"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "roic",
                            "type": "quantitative",
                            "title": "roic",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "roic",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1,
                                "symbolType": "stroke"
                            }
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "line",
                                "point": false,
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "point",
                                "tooltip": false
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 0,
                                    "condition": {
                                        "param": "shared_pivot_hover_param",
                                        "value": 1,
                                        "empty": false
                                    }
                                },
                                "size": {
                                    "value": 80
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "-5"
                                },
                                "dx": {
                                    "expr": "0"
                                },
                                "baseline": {
                                    "expr": "'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "roe",
                                    "type": "quantitative"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "roe",
                            "type": "quantitative",
                            "title": "roe",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "roe",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1,
                                "symbolType": "stroke"
                            }
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "roic",
                                        "type": "quantitative"
                                    },
                                    {
                                        "field": "roe",
                                        "type": "quantitative"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_value_metrics.datasets.layer00 = recent_year_value_metrics.to_json(orient='records')
chart_recent_year_value_metrics.display(actions=False)

# %%
import altair
chart_recent_year_value_metrics = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenuePerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "revenuePerShare",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#54A24B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenuePerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#54A24B"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "revenuePerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_1c8b887e-150b-4b66-9c83-11595b9de9dc",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_1c8b887e-150b-4b66-9c83-11595b9de9dc",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "netIncomePerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "netIncomePerShare",
                            "scale": {
                                "range": [
                                    "#EECA3B",
                                    "#EECA3B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "netIncomePerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#EECA3B"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "netIncomePerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_94144bec-e1c0-4f17-969c-98dd01e659dd",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_94144bec-e1c0-4f17-969c-98dd01e659dd",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "operatingCashFlowPerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "operatingCashFlowPerShare",
                            "scale": {
                                "range": [
                                    "#B279A2",
                                    "#B279A2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "symbol",
                            "type": "ordinal",
                            "title": "symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "operatingCashFlowPerShare",
                            "type": "quantitative",
                            "title": "cash lines per share",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#B279A2"
                        },
                        "tooltip": [
                            {
                                "field": "symbol",
                                "type": "ordinal"
                            },
                            {
                                "field": "operatingCashFlowPerShare",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_9a40b5fa-f525-4012-86c4-35dad42f90bf",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_9a40b5fa-f525-4012-86c4-35dad42f90bf",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_year_value_metrics.datasets.layer00 = recent_year_value_metrics.to_json(orient='records')
chart_recent_year_value_metrics.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     SELECT DISTINCT ff.Symbol AS ticker,
#     ff."Gross Margin",
#     ff."Oper. Margin",
#     ff."Profit Margin",
#     ff."FCF Margin",
#     ff."EBITDA Margin"
#     
#     FROM semi_supply_chain_SemiEM_Recent_Full_Financials.csv AS ff
#     LEFT JOIN semi_supply_chain_SemiEM_dcf.csv AS dcf ON ff.Symbol = dcf.Ticker
#     WHERE ff.Symbol = dcf.Ticker
#     AND 1=1;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_recent_margins = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "Gross Margin",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#ffffff",
                                "dy": {
                                    "expr": "datum[\"Gross Margin\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"Gross Margin\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"Gross Margin\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "Gross Margin",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "Gross Margin",
                                    "type": "quantitative",
                                    "title": "Gross Margin",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "Gross Margin",
                            "type": "quantitative",
                            "title": "Gross Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Gross Margin",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_3356de90_6e76_42aa_be11_484e91abc07b",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "Oper\\. Margin",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#0b0e16",
                                "dy": {
                                    "expr": "datum[\"Oper\\. Margin\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"Oper\\. Margin\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"Oper\\. Margin\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "Oper\\. Margin",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "Oper\\. Margin",
                                    "type": "quantitative",
                                    "title": "Oper. Margin",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "Oper\\. Margin",
                            "type": "quantitative",
                            "title": "Oper. Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Oper. Margin",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_2596c990_d626_4215_a8e4_440a2ad11c9d",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "EBITDA Margin",
                            "type": "quantitative",
                            "title": "EBITDA Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "EBITDA Margin",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "EBITDA Margin",
                            "type": "quantitative",
                            "title": "EBITDA Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        },
                        "tooltip": [
                            {
                                "field": "ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "EBITDA Margin",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_72575f2e-9c1f-4312-8659-1aa335cd3e4b",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_72575f2e-9c1f-4312-8659-1aa335cd3e4b",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_margins.datasets.layer00 = recent_margins.to_json(orient='records')
chart_recent_margins.display(actions=False)

# %%
import altair
chart_recent_margins = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "Profit Margin",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"Profit Margin\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"Profit Margin\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"Profit Margin\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "Profit Margin",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "Profit Margin",
                                    "type": "quantitative",
                                    "title": "Profit Margin",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "Profit Margin",
                            "type": "quantitative",
                            "title": "Profit Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Profit Margin",
                            "scale": {
                                "range": [
                                    "#4C78A8",
                                    "#4C78A8"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_3356de90_6e76_42aa_be11_484e91abc07b",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                },
                                "tooltip": [
                                    {
                                        "field": "ticker",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "FCF Margin",
                                        "type": "quantitative"
                                    }
                                ]
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#0b0e16",
                                "dy": {
                                    "expr": "2"
                                },
                                "dx": {
                                    "expr": "0"
                                },
                                "baseline": {
                                    "expr": "'middle'"
                                }
                            },
                            "transform": [
                                {
                                    "groupby": [
                                        "ticker"
                                    ],
                                    "stack": "FCF Margin",
                                    "as": [
                                        "__FCF Margin_start__",
                                        "__FCF Margin_end__"
                                    ],
                                    "offset": "zero"
                                },
                                {
                                    "calculate": "(datum[\"__FCF Margin_start__\"] + datum[\"__FCF Margin_end__\"]) / 2",
                                    "as": "__y_midpoint__"
                                }
                            ],
                            "encoding": {
                                "text": {
                                    "field": "FCF Margin",
                                    "aggregate": null,
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "__y_midpoint__",
                                    "type": "quantitative",
                                    "aggregate": null,
                                    "title": "FCF Margin",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    }
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "FCF Margin",
                            "type": "quantitative",
                            "title": "FCF Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "FCF Margin",
                            "scale": {
                                "range": [
                                    "#F58518",
                                    "#F58518"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "ticker"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_2596c990_d626_4215_a8e4_440a2ad11c9d",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "point",
                                "filled": true,
                                "clip": true
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "EBITDA Margin",
                            "type": "quantitative",
                            "title": "EBITDA Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "EBITDA Margin",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        },
                        "opacity": {
                            "value": 1
                        }
                    }
                },
                {
                    "mark": {
                        "type": "point",
                        "filled": true,
                        "clip": true
                    },
                    "encoding": {
                        "x": {
                            "field": "ticker",
                            "type": "ordinal",
                            "title": "ticker",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "EBITDA Margin",
                            "type": "quantitative",
                            "title": "EBITDA Margin",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "value": "#E45756"
                        },
                        "tooltip": [
                            {
                                "field": "ticker",
                                "type": "ordinal"
                            },
                            {
                                "field": "EBITDA Margin",
                                "type": "quantitative"
                            }
                        ],
                        "opacity": {
                            "value": 0,
                            "condition": {
                                "param": "point_hover_72575f2e-9c1f-4312-8659-1aa335cd3e4b",
                                "value": 1,
                                "empty": false
                            }
                        },
                        "size": {
                            "value": 100
                        }
                    },
                    "params": [
                        {
                            "name": "point_hover_72575f2e-9c1f-4312-8659-1aa335cd3e4b",
                            "select": {
                                "type": "point",
                                "on": "mouseover",
                                "nearest": false
                            }
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_recent_margins.datasets.layer00 = recent_margins.to_json(orient='records')
chart_recent_margins.display(actions=False)

# %% [markdown]
# Per Employee Efficiency

# %%
# import jinja2
# raw_query = """
#     select
#     Symbol,
#     (Revenue / Employees) as revenue_per_employee,
#     ("Gross Profit"	/ Employees) as grossprofit_per_employee,
#     ("Op. Income" / Employees) as opincome_per_employee,
#     (FCF / Employees) as fcf_per_employee,	
#     ("FCF - SBC" / Employees) as fcf_less_sbc_per_employee,
#     ("Net Income" / Employees) as netincome_per_employee,
#     
#     from "Health_info_services_Recent_Full_Financials.csv";
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_per_employee_efficiency = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"revenue_per_employee\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"revenue_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"revenue_per_employee\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "revenue_per_employee",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "revenue_per_employee",
                                    "type": "quantitative",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "revenue_per_employee",
                            "type": "quantitative",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "revenue_per_employee",
                            "scale": {
                                "range": [
                                    "#72B7B2",
                                    "#72B7B2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_feb800e8_b80c_42c4_b7ce_16d74417c285",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#0b0e16",
                                "dy": {
                                    "expr": "datum[\"grossprofit_per_employee\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"grossprofit_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"grossprofit_per_employee\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "grossprofit_per_employee",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "grossprofit_per_employee",
                                    "type": "quantitative",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "grossprofit_per_employee",
                            "type": "quantitative",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "grossprofit_per_employee",
                            "scale": {
                                "range": [
                                    "#BAB0AC",
                                    "#BAB0AC"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_d80d98bb_ebce_409e_9e0c_77a6de9899a4",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "Symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "revenue_per_employee",
                                        "type": "quantitative"
                                    },
                                    {
                                        "field": "grossprofit_per_employee",
                                        "type": "quantitative"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "Symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_per_employee_efficiency.datasets.layer00 = per_employee_efficiency.to_json(orient='records')
chart_per_employee_efficiency.display(actions=False)

# %%
import altair
chart_per_employee_efficiency = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"sum_opincome_per_employee\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_opincome_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_opincome_per_employee\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "opincome_per_employee",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "opincome_per_employee",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "opincome_per_employee",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Sum of opincome_per_employee",
                            "scale": {
                                "range": [
                                    "#72B7B2",
                                    "#72B7B2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_feb800e8_b80c_42c4_b7ce_16d74417c285",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#0b0e16",
                                "dy": {
                                    "expr": "datum[\"sum_netincome_per_employee\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_netincome_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_netincome_per_employee\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "netincome_per_employee",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "netincome_per_employee",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "netincome_per_employee",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Sum of netincome_per_employee",
                            "scale": {
                                "range": [
                                    "#BAB0AC",
                                    "#BAB0AC"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_d80d98bb_ebce_409e_9e0c_77a6de9899a4",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "Symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "opincome_per_employee",
                                        "type": "quantitative",
                                        "aggregate": "sum"
                                    },
                                    {
                                        "field": "netincome_per_employee",
                                        "type": "quantitative",
                                        "aggregate": "sum"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "Symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_per_employee_efficiency.datasets.layer00 = per_employee_efficiency.to_json(orient='records')
chart_per_employee_efficiency.display(actions=False)

# %%
import altair
chart_per_employee_efficiency = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "dy": {
                                    "expr": "datum[\"sum_fcf_per_employee\"] < 0 ? 2 : -2"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_fcf_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_fcf_per_employee\"] > 0 ? 'bottom' : 'top'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "fcf_per_employee",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "fcf_per_employee",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "fcf_per_employee",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Sum of fcf_per_employee",
                            "scale": {
                                "range": [
                                    "#72B7B2",
                                    "#72B7B2"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_feb800e8_b80c_42c4_b7ce_16d74417c285",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        },
                        {
                            "mark": {
                                "type": "text",
                                "fill": "#0b0e16",
                                "dy": {
                                    "expr": "datum[\"sum_fcf_less_sbc_per_employee\"] < 0 ? -4 : 4"
                                },
                                "dx": {
                                    "expr": "datum[\"sum_fcf_less_sbc_per_employee\"] < 0 ? 0 : 0"
                                },
                                "baseline": {
                                    "expr": "datum[\"sum_fcf_less_sbc_per_employee\"] > 0 ? 'top' : 'bottom'"
                                }
                            },
                            "transform": [],
                            "encoding": {
                                "text": {
                                    "field": "fcf_less_sbc_per_employee",
                                    "aggregate": "sum",
                                    "type": "quantitative"
                                },
                                "y": {
                                    "field": "fcf_less_sbc_per_employee",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "$s Per Employee",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "fcf_less_sbc_per_employee",
                            "type": "quantitative",
                            "aggregate": "sum",
                            "title": "$s Per Employee",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Sum of fcf_less_sbc_per_employee",
                            "scale": {
                                "range": [
                                    "#BAB0AC",
                                    "#BAB0AC"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_d80d98bb_ebce_409e_9e0c_77a6de9899a4",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "Symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "fcf_per_employee",
                                        "type": "quantitative",
                                        "aggregate": "sum"
                                    },
                                    {
                                        "field": "fcf_less_sbc_per_employee",
                                        "type": "quantitative",
                                        "aggregate": "sum"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "Symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_per_employee_efficiency.datasets.layer00 = per_employee_efficiency.to_json(orient='records')
chart_per_employee_efficiency.display(actions=False)

# %%
# import jinja2
# raw_query = """
#     SELECT ff.Symbol, ci.market_cap_category, ff."Total Cash", ff."Total Debt"
#     
#     FROM 'Health_info_services_Recent_Full_Financials.csv' as ff
#     LEFT JOIN 'Health_info_services_company_info.csv' as ci
#     ON ff.Symbol = ci.symbol
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_cash_to_debt = altair.Chart.from_json("""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "Total Debt",
                            "type": "quantitative",
                            "title": "Total Debt",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Total Debt",
                            "scale": {
                                "range": [
                                    "#E45756",
                                    "#E45756"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_7ef0d42d_077c_4d50_83c4_c90aa10556eb",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "transform": [],
                    "layer": [
                        {
                            "mark": {
                                "type": "bar",
                                "clip": true,
                                "filled": true
                            },
                            "encoding": {
                                "opacity": {
                                    "value": 1
                                }
                            }
                        }
                    ],
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "y": {
                            "field": "Total Cash",
                            "type": "quantitative",
                            "title": "Total Cash",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        },
                        "color": {
                            "datum": "Total Cash",
                            "scale": {
                                "range": [
                                    "#54A24B",
                                    "#54A24B"
                                ]
                            },
                            "legend": {
                                "symbolOpacity": 1
                            }
                        }
                    }
                },
                {
                    "transform": [
                        {
                            "aggregate": [],
                            "groupby": [
                                "Symbol"
                            ]
                        },
                        {
                            "window": [
                                {
                                    "op": "rank",
                                    "as": "rank"
                                }
                            ]
                        },
                        {
                            "filter": "datum.rank <= 21"
                        }
                    ],
                    "mark": {
                        "type": "rule",
                        "clip": true
                    },
                    "name": "aggregate_xAxis_spec_326db21e_4dac_43f0_b360_abb0a7a416a5",
                    "encoding": {
                        "opacity": {
                            "value": 0
                        }
                    }
                },
                {
                    "encoding": {
                        "x": {
                            "field": "Symbol",
                            "type": "ordinal",
                            "title": "Symbol",
                            "scale": {},
                            "axis": {
                                "grid": true,
                                "ticks": true,
                                "labels": true,
                                "labelFlush": false
                            }
                        }
                    },
                    "layer": [
                        {
                            "mark": {
                                "type": "rule",
                                "clip": true
                            },
                            "encoding": {
                                "opacity": {
                                    "condition": {
                                        "value": 0.3,
                                        "param": "shared_pivot_hover_param",
                                        "empty": false
                                    },
                                    "value": 0
                                },
                                "color": {
                                    "value": "CHART_DEFAULT_RULE_COLOR_MARKER"
                                },
                                "tooltip": [
                                    {
                                        "field": "Symbol",
                                        "type": "ordinal"
                                    },
                                    {
                                        "field": "Total Debt",
                                        "type": "quantitative"
                                    },
                                    {
                                        "field": "Total Cash",
                                        "type": "quantitative"
                                    }
                                ]
                            },
                            "params": [
                                {
                                    "name": "shared_pivot_hover_param",
                                    "select": {
                                        "type": "point",
                                        "fields": [
                                            "Symbol"
                                        ],
                                        "nearest": true,
                                        "on": "mouseover",
                                        "clear": "mouseout"
                                    }
                                }
                            ]
                        }
                    ]
                }
            ]
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {}
    }
}
""")
chart_cash_to_debt.datasets.layer00 = cash_to_debt.to_json(orient='records')
chart_cash_to_debt.display(actions=False)
